# %% [markdown]
# # vanishing gradient modified

# %% [markdown]
# ## multi layer network class

# %%
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
from common import layers
from collections import OrderedDict
from common import functions
from data.mnist import load_mnist
import matplotlib.pyplot as plt


class MultiLayerNet:
    '''
    input_size: 入力層のノード数
    hidden_size_list: 隠れ層のノード数のリスト
    output_size: 出力層のノード数
    activation: 活性化関数
    weight_init_std: 重みの初期化方法
    '''
    def __init__(self, input_size, hidden_size_list, output_size, activation='relu', weight_init_std='relu'):
        self.input_size = input_size
        self.output_size = output_size
        self.hidden_size_list = hidden_size_list
        self.hidden_layer_num = len(hidden_size_list)
        self.params = {}

        # 重みの初期化
        self.__init_weight(weight_init_std)

        # レイヤの生成, sigmoidとreluのみ扱う
        activation_layer = {'sigmoid': layers.Sigmoid, 'relu': layers.Relu}
        self.layers = OrderedDict() # 追加した順番に格納
        for idx in range(1, self.hidden_layer_num+1):
            self.layers['Affine' + str(idx)] = layers.Affine(self.params['W' + str(idx)], self.params['b' + str(idx)])
            self.layers['Activation_function' + str(idx)] = activation_layer[activation]()

        idx = self.hidden_layer_num + 1
        self.layers['Affine' + str(idx)] = layers.Affine(self.params['W' + str(idx)], self.params['b' + str(idx)])

        self.last_layer = layers.SoftmaxWithLoss()

    def __init_weight(self, weight_init_std):
        all_size_list = [self.input_size] + self.hidden_size_list + [self.output_size]
        for idx in range(1, len(all_size_list)):
            scale = weight_init_std
            if str(weight_init_std).lower() in ('relu', 'he'):
                scale = np.sqrt(2.0 / all_size_list[idx - 1])
            elif str(weight_init_std).lower() in ('sigmoid', 'xavier'):
                scale = np.sqrt(1.0 / all_size_list[idx - 1])

            self.params['W' + str(idx)] = scale * np.random.randn(all_size_list[idx-1], all_size_list[idx])
            self.params['b' + str(idx)] = np.zeros(all_size_list[idx])

    def predict(self, x):
        for layer in self.layers.values():
            x = layer.forward(x)

        return x

    def loss(self, x, d):
        y = self.predict(x)

        weight_decay = 0
        for idx in range(1, self.hidden_layer_num + 2):
            W = self.params['W' + str(idx)]

        return self.last_layer.forward(y, d) + weight_decay

    def accuracy(self, x, d):
        y = self.predict(x)
        y = np.argmax(y, axis=1)
        if d.ndim != 1 : d = np.argmax(d, axis=1)

        accuracy = np.sum(y == d) / float(x.shape[0])
        return accuracy

    def gradient(self, x, d):
        # forward
        self.loss(x, d)

        # backward
        dout = 1
        dout = self.last_layer.backward(dout)

        layers = list(self.layers.values())
        layers.reverse()
        for layer in layers:
            dout = layer.backward(dout)

        # 設定
        grad = {}
        for idx in range(1, self.hidden_layer_num+2):
            grad['W' + str(idx)] = self.layers['Affine' + str(idx)].dW
            grad['b' + str(idx)] = self.layers['Affine' + str(idx)].db

        return grad

# %% [markdown]
# ## vanishing sample
# ## sigmoid - gauss

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std=0.01)

iters_num = 2000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)
    
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.13
#                 : 10. 正答率(テスト) = 0.1028
# Generation: 20. 正答率(トレーニング) = 0.13
#                 : 20. 正答率(テスト) = 0.1028
# Generation: 30. 正答率(トレーニング) = 0.12
#                 : 30. 正答率(テスト) = 0.101
# Generation: 40. 正答率(トレーニング) = 0.1
#                 : 40. 正答率(テスト) = 0.1028
# Generation: 50. 正答率(トレーニング) = 0.12
#                 : 50. 正答率(テスト) = 0.1028
# Generation: 60. 正答率(トレーニング) = 0.1
#                 : 60. 正答率(テスト) = 0.101
# Generation: 70. 正答率(トレーニング) = 0.12
#                 : 70. 正答率(テスト) = 0.1135
# Generation: 80. 正答率(トレーニング) = 0.14
#                 : 80. 正答率(テスト) = 0.1135
# Generation: 90. 正答率(トレーニング) = 0.15
#                 : 90. 正答率(テスト) = 0.1135
# Generation: 100. 正答率(トレーニング) = 0.11
#                 : 100. 正答率(テスト) = 0.1135
# Generation: 110. 正答率(トレーニング) = 0.11
#                 : 110. 正答率(テスト) = 0.1135
# Generation: 120. 正答率(トレーニング) = 0.13
#                 : 120. 正答率(テスト) = 0.1135
# Generation: 130. 正答率(トレーニング) = 0.12
#                 : 130. 正答率(テスト) = 0.1135
# Generation: 140. 正答率(トレーニング) = 0.15
#                 : 140. 正答率(テスト) = 0.1135
# Generation: 150. 正答率(トレーニング) = 0.08
#                 : 150. 正答率(テスト) = 0.1009
# Generation: 160. 正答率(トレーニング) = 0.14
#                 : 160. 正答率(テスト) = 0.1135
# Generation: 170. 正答率(トレーニング) = 0.11
#                 : 170. 正答率(テスト) = 0.1135
# Generation: 180. 正答率(トレーニング) = 0.14
#                 : 180. 正答率(テスト) = 0.101
# Generation: 190. 正答率(トレーニング) = 0.1
#                 : 190. 正答率(テスト) = 0.101
# Generation: 200. 正答率(トレーニング) = 0.1
#                 : 200. 正答率(テスト) = 0.1135
# Generation: 210. 正答率(トレーニング) = 0.1
#                 : 210. 正答率(テスト) = 0.1028
# Generation: 220. 正答率(トレーニング) = 0.17
#                 : 220. 正答率(テスト) = 0.1028
# Generation: 230. 正答率(トレーニング) = 0.11
#                 : 230. 正答率(テスト) = 0.1135
# Generation: 240. 正答率(トレーニング) = 0.15
#                 : 240. 正答率(テスト) = 0.1135
# Generation: 250. 正答率(トレーニング) = 0.13
#                 : 250. 正答率(テスト) = 0.1135
# Generation: 260. 正答率(トレーニング) = 0.15
#                 : 260. 正答率(テスト) = 0.1135
# Generation: 270. 正答率(トレーニング) = 0.09
#                 : 270. 正答率(テスト) = 0.1135
# Generation: 280. 正答率(トレーニング) = 0.1
#                 : 280. 正答率(テスト) = 0.1135
# Generation: 290. 正答率(トレーニング) = 0.16
#                 : 290. 正答率(テスト) = 0.1135
# Generation: 300. 正答率(トレーニング) = 0.08
#                 : 300. 正答率(テスト) = 0.1135
# Generation: 310. 正答率(トレーニング) = 0.12
#                 : 310. 正答率(テスト) = 0.1135
# Generation: 320. 正答率(トレーニング) = 0.11
#                 : 320. 正答率(テスト) = 0.1135
# Generation: 330. 正答率(トレーニング) = 0.13
#                 : 330. 正答率(テスト) = 0.1135
# Generation: 340. 正答率(トレーニング) = 0.17
#                 : 340. 正答率(テスト) = 0.1032
# Generation: 350. 正答率(トレーニング) = 0.11
#                 : 350. 正答率(テスト) = 0.1135
# Generation: 360. 正答率(トレーニング) = 0.1
#                 : 360. 正答率(テスト) = 0.1135
# Generation: 370. 正答率(トレーニング) = 0.12
#                 : 370. 正答率(テスト) = 0.1135
# Generation: 380. 正答率(トレーニング) = 0.06
#                 : 380. 正答率(テスト) = 0.1135
# Generation: 390. 正答率(トレーニング) = 0.13
#                 : 390. 正答率(テスト) = 0.1135
# Generation: 400. 正答率(トレーニング) = 0.08
#                 : 400. 正答率(テスト) = 0.1135
# Generation: 410. 正答率(トレーニング) = 0.12
#                 : 410. 正答率(テスト) = 0.0974
# Generation: 420. 正答率(トレーニング) = 0.16
#                 : 420. 正答率(テスト) = 0.1028
# Generation: 430. 正答率(トレーニング) = 0.08
#                 : 430. 正答率(テスト) = 0.1135
# Generation: 440. 正答率(トレーニング) = 0.09
#                 : 440. 正答率(テスト) = 0.101
# Generation: 450. 正答率(トレーニング) = 0.12
#                 : 450. 正答率(テスト) = 0.101
# Generation: 460. 正答率(トレーニング) = 0.12
#                 : 460. 正答率(テスト) = 0.1032
# Generation: 470. 正答率(トレーニング) = 0.12
#                 : 470. 正答率(テスト) = 0.1028
# Generation: 480. 正答率(トレーニング) = 0.12
#                 : 480. 正答率(テスト) = 0.1028
# Generation: 490. 正答率(トレーニング) = 0.16
#                 : 490. 正答率(テスト) = 0.1135
# Generation: 500. 正答率(トレーニング) = 0.07
#                 : 500. 正答率(テスト) = 0.1135
# Generation: 510. 正答率(トレーニング) = 0.13
#                 : 510. 正答率(テスト) = 0.1135
# Generation: 520. 正答率(トレーニング) = 0.11
#                 : 520. 正答率(テスト) = 0.1135
# Generation: 530. 正答率(トレーニング) = 0.11
#                 : 530. 正答率(テスト) = 0.1135
# Generation: 540. 正答率(トレーニング) = 0.11
#                 : 540. 正答率(テスト) = 0.1135
# Generation: 550. 正答率(トレーニング) = 0.15
#                 : 550. 正答率(テスト) = 0.1028
# Generation: 560. 正答率(トレーニング) = 0.1
#                 : 560. 正答率(テスト) = 0.1135
# Generation: 570. 正答率(トレーニング) = 0.1
#                 : 570. 正答率(テスト) = 0.1135
# Generation: 580. 正答率(トレーニング) = 0.13
#                 : 580. 正答率(テスト) = 0.101
# Generation: 590. 正答率(トレーニング) = 0.12
#                 : 590. 正答率(テスト) = 0.1135
# Generation: 600. 正答率(トレーニング) = 0.12
#                 : 600. 正答率(テスト) = 0.1135
# Generation: 610. 正答率(トレーニング) = 0.1
#                 : 610. 正答率(テスト) = 0.101
# Generation: 620. 正答率(トレーニング) = 0.11
#                 : 620. 正答率(テスト) = 0.101
# Generation: 630. 正答率(トレーニング) = 0.15
#                 : 630. 正答率(テスト) = 0.1135
# Generation: 640. 正答率(トレーニング) = 0.12
#                 : 640. 正答率(テスト) = 0.1135
# Generation: 650. 正答率(トレーニング) = 0.18
#                 : 650. 正答率(テスト) = 0.1135
# Generation: 660. 正答率(トレーニング) = 0.13
#                 : 660. 正答率(テスト) = 0.1135
# Generation: 670. 正答率(トレーニング) = 0.07
#                 : 670. 正答率(テスト) = 0.1135
# Generation: 680. 正答率(トレーニング) = 0.14
#                 : 680. 正答率(テスト) = 0.1135
# Generation: 690. 正答率(トレーニング) = 0.09
#                 : 690. 正答率(テスト) = 0.1135
# Generation: 700. 正答率(トレーニング) = 0.15
#                 : 700. 正答率(テスト) = 0.1135
# Generation: 710. 正答率(トレーニング) = 0.14
#                 : 710. 正答率(テスト) = 0.1028
# Generation: 720. 正答率(トレーニング) = 0.13
#                 : 720. 正答率(テスト) = 0.1135
# Generation: 730. 正答率(トレーニング) = 0.13
#                 : 730. 正答率(テスト) = 0.1028
# Generation: 740. 正答率(トレーニング) = 0.16
#                 : 740. 正答率(テスト) = 0.1135
# Generation: 750. 正答率(トレーニング) = 0.12
#                 : 750. 正答率(テスト) = 0.1135
# Generation: 760. 正答率(トレーニング) = 0.07
#                 : 760. 正答率(テスト) = 0.1135
# Generation: 770. 正答率(トレーニング) = 0.14
#                 : 770. 正答率(テスト) = 0.1135
# Generation: 780. 正答率(トレーニング) = 0.12
#                 : 780. 正答率(テスト) = 0.1135
# Generation: 790. 正答率(トレーニング) = 0.1
#                 : 790. 正答率(テスト) = 0.1135
# Generation: 800. 正答率(トレーニング) = 0.13
#                 : 800. 正答率(テスト) = 0.1135
# Generation: 810. 正答率(トレーニング) = 0.1
#                 : 810. 正答率(テスト) = 0.1135
# Generation: 820. 正答率(トレーニング) = 0.17
#                 : 820. 正答率(テスト) = 0.101
# Generation: 830. 正答率(トレーニング) = 0.14
#                 : 830. 正答率(テスト) = 0.1135
# Generation: 840. 正答率(トレーニング) = 0.1
#                 : 840. 正答率(テスト) = 0.1135
# Generation: 850. 正答率(トレーニング) = 0.12
#                 : 850. 正答率(テスト) = 0.1028
# Generation: 860. 正答率(トレーニング) = 0.1
#                 : 860. 正答率(テスト) = 0.1028
# Generation: 870. 正答率(トレーニング) = 0.16
#                 : 870. 正答率(テスト) = 0.1135
# Generation: 880. 正答率(トレーニング) = 0.16
#                 : 880. 正答率(テスト) = 0.1135
# Generation: 890. 正答率(トレーニング) = 0.15
#                 : 890. 正答率(テスト) = 0.1028
# Generation: 900. 正答率(トレーニング) = 0.11
#                 : 900. 正答率(テスト) = 0.1135
# Generation: 910. 正答率(トレーニング) = 0.09
#                 : 910. 正答率(テスト) = 0.1135
# Generation: 920. 正答率(トレーニング) = 0.08
#                 : 920. 正答率(テスト) = 0.1135
# Generation: 930. 正答率(トレーニング) = 0.06
#                 : 930. 正答率(テスト) = 0.1028
# Generation: 940. 正答率(トレーニング) = 0.12
#                 : 940. 正答率(テスト) = 0.1135
# Generation: 950. 正答率(トレーニング) = 0.09
#                 : 950. 正答率(テスト) = 0.1135
# Generation: 960. 正答率(トレーニング) = 0.21
#                 : 960. 正答率(テスト) = 0.1135
# Generation: 970. 正答率(トレーニング) = 0.15
#                 : 970. 正答率(テスト) = 0.1135
# Generation: 980. 正答率(トレーニング) = 0.14
#                 : 980. 正答率(テスト) = 0.1135
# Generation: 990. 正答率(トレーニング) = 0.13
#                 : 990. 正答率(テスト) = 0.0958
# Generation: 1000. 正答率(トレーニング) = 0.09
#                 : 1000. 正答率(テスト) = 0.1135
# Generation: 1010. 正答率(トレーニング) = 0.14
#                 : 1010. 正答率(テスト) = 0.1135
# Generation: 1020. 正答率(トレーニング) = 0.12
#                 : 1020. 正答率(テスト) = 0.1135
# Generation: 1030. 正答率(トレーニング) = 0.17
#                 : 1030. 正答率(テスト) = 0.1135
# Generation: 1040. 正答率(トレーニング) = 0.09
#                 : 1040. 正答率(テスト) = 0.0958
# Generation: 1050. 正答率(トレーニング) = 0.12
#                 : 1050. 正答率(テスト) = 0.1135
# Generation: 1060. 正答率(トレーニング) = 0.2
#                 : 1060. 正答率(テスト) = 0.1135
# Generation: 1070. 正答率(トレーニング) = 0.11
#                 : 1070. 正答率(テスト) = 0.1135
# Generation: 1080. 正答率(トレーニング) = 0.06
#                 : 1080. 正答率(テスト) = 0.1135
# Generation: 1090. 正答率(トレーニング) = 0.1
#                 : 1090. 正答率(テスト) = 0.1135
# Generation: 1100. 正答率(トレーニング) = 0.13
#                 : 1100. 正答率(テスト) = 0.1135
# Generation: 1110. 正答率(トレーニング) = 0.2
#                 : 1110. 正答率(テスト) = 0.1135
# Generation: 1120. 正答率(トレーニング) = 0.1
#                 : 1120. 正答率(テスト) = 0.1135
# Generation: 1130. 正答率(トレーニング) = 0.13
#                 : 1130. 正答率(テスト) = 0.1135
# Generation: 1140. 正答率(トレーニング) = 0.11
#                 : 1140. 正答率(テスト) = 0.1135
# Generation: 1150. 正答率(トレーニング) = 0.08
#                 : 1150. 正答率(テスト) = 0.1032
# Generation: 1160. 正答率(トレーニング) = 0.11
#                 : 1160. 正答率(テスト) = 0.1032
# Generation: 1170. 正答率(トレーニング) = 0.1
#                 : 1170. 正答率(テスト) = 0.1135
# Generation: 1180. 正答率(トレーニング) = 0.18
#                 : 1180. 正答率(テスト) = 0.1135
# Generation: 1190. 正答率(トレーニング) = 0.12
#                 : 1190. 正答率(テスト) = 0.1135
# Generation: 1200. 正答率(トレーニング) = 0.11
#                 : 1200. 正答率(テスト) = 0.1135
# Generation: 1210. 正答率(トレーニング) = 0.15
#                 : 1210. 正答率(テスト) = 0.1135
# Generation: 1220. 正答率(トレーニング) = 0.1
#                 : 1220. 正答率(テスト) = 0.1135
# Generation: 1230. 正答率(トレーニング) = 0.13
#                 : 1230. 正答率(テスト) = 0.1135
# Generation: 1240. 正答率(トレーニング) = 0.11
#                 : 1240. 正答率(テスト) = 0.1135
# Generation: 1250. 正答率(トレーニング) = 0.15
#                 : 1250. 正答率(テスト) = 0.1135
# Generation: 1260. 正答率(トレーニング) = 0.14
#                 : 1260. 正答率(テスト) = 0.101
# Generation: 1270. 正答率(トレーニング) = 0.13
#                 : 1270. 正答率(テスト) = 0.1135
# Generation: 1280. 正答率(トレーニング) = 0.12
#                 : 1280. 正答率(テスト) = 0.1135
# Generation: 1290. 正答率(トレーニング) = 0.15
#                 : 1290. 正答率(テスト) = 0.1135
# Generation: 1300. 正答率(トレーニング) = 0.1
#                 : 1300. 正答率(テスト) = 0.1135
# Generation: 1310. 正答率(トレーニング) = 0.16
#                 : 1310. 正答率(テスト) = 0.1135
# Generation: 1320. 正答率(トレーニング) = 0.12
#                 : 1320. 正答率(テスト) = 0.1135
# Generation: 1330. 正答率(トレーニング) = 0.06
#                 : 1330. 正答率(テスト) = 0.1135
# Generation: 1340. 正答率(トレーニング) = 0.1
#                 : 1340. 正答率(テスト) = 0.1135
# Generation: 1350. 正答率(トレーニング) = 0.1
#                 : 1350. 正答率(テスト) = 0.1135
# Generation: 1360. 正答率(トレーニング) = 0.13
#                 : 1360. 正答率(テスト) = 0.1135
# Generation: 1370. 正答率(トレーニング) = 0.08
#                 : 1370. 正答率(テスト) = 0.1135
# Generation: 1380. 正答率(トレーニング) = 0.08
#                 : 1380. 正答率(テスト) = 0.1135
# Generation: 1390. 正答率(トレーニング) = 0.13
#                 : 1390. 正答率(テスト) = 0.1135
# Generation: 1400. 正答率(トレーニング) = 0.05
#                 : 1400. 正答率(テスト) = 0.1028
# Generation: 1410. 正答率(トレーニング) = 0.16
#                 : 1410. 正答率(テスト) = 0.1135
# Generation: 1420. 正答率(トレーニング) = 0.14
#                 : 1420. 正答率(テスト) = 0.1135
# Generation: 1430. 正答率(トレーニング) = 0.19
#                 : 1430. 正答率(テスト) = 0.1135
# Generation: 1440. 正答率(トレーニング) = 0.1
#                 : 1440. 正答率(テスト) = 0.1135
# Generation: 1450. 正答率(トレーニング) = 0.09
#                 : 1450. 正答率(テスト) = 0.1135
# Generation: 1460. 正答率(トレーニング) = 0.11
#                 : 1460. 正答率(テスト) = 0.1135
# Generation: 1470. 正答率(トレーニング) = 0.1
#                 : 1470. 正答率(テスト) = 0.1032
# Generation: 1480. 正答率(トレーニング) = 0.09
#                 : 1480. 正答率(テスト) = 0.0958
# Generation: 1490. 正答率(トレーニング) = 0.17
#                 : 1490. 正答率(テスト) = 0.1135
# Generation: 1500. 正答率(トレーニング) = 0.13
#                 : 1500. 正答率(テスト) = 0.1135
# Generation: 1510. 正答率(トレーニング) = 0.14
#                 : 1510. 正答率(テスト) = 0.1135
# Generation: 1520. 正答率(トレーニング) = 0.07
#                 : 1520. 正答率(テスト) = 0.1135
# Generation: 1530. 正答率(トレーニング) = 0.09
#                 : 1530. 正答率(テスト) = 0.1135
# Generation: 1540. 正答率(トレーニング) = 0.11
#                 : 1540. 正答率(テスト) = 0.1135
# Generation: 1550. 正答率(トレーニング) = 0.14
#                 : 1550. 正答率(テスト) = 0.1135
# Generation: 1560. 正答率(トレーニング) = 0.15
#                 : 1560. 正答率(テスト) = 0.1135
# Generation: 1570. 正答率(トレーニング) = 0.19
#                 : 1570. 正答率(テスト) = 0.1135
# Generation: 1580. 正答率(トレーニング) = 0.06
#                 : 1580. 正答率(テスト) = 0.1135
# Generation: 1590. 正答率(トレーニング) = 0.12
#                 : 1590. 正答率(テスト) = 0.1135
# Generation: 1600. 正答率(トレーニング) = 0.1
#                 : 1600. 正答率(テスト) = 0.1135
# Generation: 1610. 正答率(トレーニング) = 0.13
#                 : 1610. 正答率(テスト) = 0.1135
# Generation: 1620. 正答率(トレーニング) = 0.13
#                 : 1620. 正答率(テスト) = 0.1135
# Generation: 1630. 正答率(トレーニング) = 0.12
#                 : 1630. 正答率(テスト) = 0.1135
# Generation: 1640. 正答率(トレーニング) = 0.17
#                 : 1640. 正答率(テスト) = 0.1135
# Generation: 1650. 正答率(トレーニング) = 0.12
#                 : 1650. 正答率(テスト) = 0.1135
# Generation: 1660. 正答率(トレーニング) = 0.11
#                 : 1660. 正答率(テスト) = 0.1135
# Generation: 1670. 正答率(トレーニング) = 0.1
#                 : 1670. 正答率(テスト) = 0.1135
# Generation: 1680. 正答率(トレーニング) = 0.08
#                 : 1680. 正答率(テスト) = 0.1135
# Generation: 1690. 正答率(トレーニング) = 0.15
#                 : 1690. 正答率(テスト) = 0.1135
# Generation: 1700. 正答率(トレーニング) = 0.08
#                 : 1700. 正答率(テスト) = 0.1135
# Generation: 1710. 正答率(トレーニング) = 0.2
#                 : 1710. 正答率(テスト) = 0.1135
# Generation: 1720. 正答率(トレーニング) = 0.08
#                 : 1720. 正答率(テスト) = 0.1135
# Generation: 1730. 正答率(トレーニング) = 0.13
#                 : 1730. 正答率(テスト) = 0.1135
# Generation: 1740. 正答率(トレーニング) = 0.09
#                 : 1740. 正答率(テスト) = 0.1135
# Generation: 1750. 正答率(トレーニング) = 0.11
#                 : 1750. 正答率(テスト) = 0.1135
# Generation: 1760. 正答率(トレーニング) = 0.1
#                 : 1760. 正答率(テスト) = 0.1135
# Generation: 1770. 正答率(トレーニング) = 0.14
#                 : 1770. 正答率(テスト) = 0.1135
# Generation: 1780. 正答率(トレーニング) = 0.11
#                 : 1780. 正答率(テスト) = 0.1135
# Generation: 1790. 正答率(トレーニング) = 0.17
#                 : 1790. 正答率(テスト) = 0.1135
# Generation: 1800. 正答率(トレーニング) = 0.06
#                 : 1800. 正答率(テスト) = 0.1135
# Generation: 1810. 正答率(トレーニング) = 0.08
#                 : 1810. 正答率(テスト) = 0.1135
# Generation: 1820. 正答率(トレーニング) = 0.1
#                 : 1820. 正答率(テスト) = 0.0958
# Generation: 1830. 正答率(トレーニング) = 0.14
#                 : 1830. 正答率(テスト) = 0.101
# Generation: 1840. 正答率(トレーニング) = 0.07
#                 : 1840. 正答率(テスト) = 0.114
# Generation: 1850. 正答率(トレーニング) = 0.09
#                 : 1850. 正答率(テスト) = 0.101
# Generation: 1860. 正答率(トレーニング) = 0.08
#                 : 1860. 正答率(テスト) = 0.1009
# Generation: 1870. 正答率(トレーニング) = 0.16
#                 : 1870. 正答率(テスト) = 0.1135
# Generation: 1880. 正答率(トレーニング) = 0.14
#                 : 1880. 正答率(テスト) = 0.1135
# Generation: 1890. 正答率(トレーニング) = 0.12
#                 : 1890. 正答率(テスト) = 0.101
# Generation: 1900. 正答率(トレーニング) = 0.13
#                 : 1900. 正答率(テスト) = 0.1135
# Generation: 1910. 正答率(トレーニング) = 0.08
#                 : 1910. 正答率(テスト) = 0.1135
# Generation: 1920. 正答率(トレーニング) = 0.08
#                 : 1920. 正答率(テスト) = 0.1135
# Generation: 1930. 正答率(トレーニング) = 0.12
#                 : 1930. 正答率(テスト) = 0.1135
# Generation: 1940. 正答率(トレーニング) = 0.06
#                 : 1940. 正答率(テスト) = 0.1135
# Generation: 1950. 正答率(トレーニング) = 0.11
#                 : 1950. 正答率(テスト) = 0.1028
# Generation: 1960. 正答率(トレーニング) = 0.11
#                 : 1960. 正答率(テスト) = 0.1135
# Generation: 1970. 正答率(トレーニング) = 0.09
#                 : 1970. 正答率(テスト) = 0.1135
# Generation: 1980. 正答率(トレーニング) = 0.1
#                 : 1980. 正答率(テスト) = 0.1135
# Generation: 1990. 正答率(トレーニング) = 0.11
#                 : 1990. 正答率(テスト) = 0.1009
# Generation: 2000. 正答率(トレーニング) = 0.18
#                 : 2000. 正答率(テスト) = 0.1028

# %% [markdown]
# ## ReLU - gauss

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='relu', weight_init_std=0.01)

iters_num = 2000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)
    
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.08
#                 : 10. 正答率(テスト) = 0.0892
# Generation: 20. 正答率(トレーニング) = 0.09
#                 : 20. 正答率(テスト) = 0.1028
# Generation: 30. 正答率(トレーニング) = 0.17
#                 : 30. 正答率(テスト) = 0.1135
# Generation: 40. 正答率(トレーニング) = 0.05
#                 : 40. 正答率(テスト) = 0.1135
# Generation: 50. 正答率(トレーニング) = 0.09
#                 : 50. 正答率(テスト) = 0.1028
# Generation: 60. 正答率(トレーニング) = 0.15
#                 : 60. 正答率(テスト) = 0.1135
# Generation: 70. 正答率(トレーニング) = 0.13
#                 : 70. 正答率(テスト) = 0.1135
# Generation: 80. 正答率(トレーニング) = 0.12
#                 : 80. 正答率(テスト) = 0.1135
# Generation: 90. 正答率(トレーニング) = 0.13
#                 : 90. 正答率(テスト) = 0.1135
# Generation: 100. 正答率(トレーニング) = 0.16
#                 : 100. 正答率(テスト) = 0.1135
# Generation: 110. 正答率(トレーニング) = 0.12
#                 : 110. 正答率(テスト) = 0.1433
# Generation: 120. 正答率(トレーニング) = 0.16
#                 : 120. 正答率(テスト) = 0.1135
# Generation: 130. 正答率(トレーニング) = 0.14
#                 : 130. 正答率(テスト) = 0.1135
# Generation: 140. 正答率(トレーニング) = 0.13
#                 : 140. 正答率(テスト) = 0.1135
# Generation: 150. 正答率(トレーニング) = 0.08
#                 : 150. 正答率(テスト) = 0.1135
# Generation: 160. 正答率(トレーニング) = 0.14
#                 : 160. 正答率(テスト) = 0.1135
# Generation: 170. 正答率(トレーニング) = 0.14
#                 : 170. 正答率(テスト) = 0.1135
# Generation: 180. 正答率(トレーニング) = 0.11
#                 : 180. 正答率(テスト) = 0.1135
# Generation: 190. 正答率(トレーニング) = 0.13
#                 : 190. 正答率(テスト) = 0.1135
# Generation: 200. 正答率(トレーニング) = 0.11
#                 : 200. 正答率(テスト) = 0.1135
# Generation: 210. 正答率(トレーニング) = 0.13
#                 : 210. 正答率(テスト) = 0.1135
# Generation: 220. 正答率(トレーニング) = 0.13
#                 : 220. 正答率(テスト) = 0.1135
# Generation: 230. 正答率(トレーニング) = 0.09
#                 : 230. 正答率(テスト) = 0.1135
# Generation: 240. 正答率(トレーニング) = 0.14
#                 : 240. 正答率(テスト) = 0.1135
# Generation: 250. 正答率(トレーニング) = 0.07
#                 : 250. 正答率(テスト) = 0.1135
# Generation: 260. 正答率(トレーニング) = 0.13
#                 : 260. 正答率(テスト) = 0.1135
# Generation: 270. 正答率(トレーニング) = 0.1
#                 : 270. 正答率(テスト) = 0.1135
# Generation: 280. 正答率(トレーニング) = 0.1
#                 : 280. 正答率(テスト) = 0.1135
# Generation: 290. 正答率(トレーニング) = 0.13
#                 : 290. 正答率(テスト) = 0.1135
# Generation: 300. 正答率(トレーニング) = 0.12
#                 : 300. 正答率(テスト) = 0.1135
# Generation: 310. 正答率(トレーニング) = 0.09
#                 : 310. 正答率(テスト) = 0.1135
# Generation: 320. 正答率(トレーニング) = 0.15
#                 : 320. 正答率(テスト) = 0.1135
# Generation: 330. 正答率(トレーニング) = 0.22
#                 : 330. 正答率(テスト) = 0.1135
# Generation: 340. 正答率(トレーニング) = 0.12
#                 : 340. 正答率(テスト) = 0.1135
# Generation: 350. 正答率(トレーニング) = 0.11
#                 : 350. 正答率(テスト) = 0.1135
# Generation: 360. 正答率(トレーニング) = 0.16
#                 : 360. 正答率(テスト) = 0.1135
# Generation: 370. 正答率(トレーニング) = 0.1
#                 : 370. 正答率(テスト) = 0.1135
# Generation: 380. 正答率(トレーニング) = 0.09
#                 : 380. 正答率(テスト) = 0.1135
# Generation: 390. 正答率(トレーニング) = 0.05
#                 : 390. 正答率(テスト) = 0.1135
# Generation: 400. 正答率(トレーニング) = 0.1
#                 : 400. 正答率(テスト) = 0.1262
# Generation: 410. 正答率(トレーニング) = 0.21
#                 : 410. 正答率(テスト) = 0.1981
# Generation: 420. 正答率(トレーニング) = 0.21
#                 : 420. 正答率(テスト) = 0.2096
# Generation: 430. 正答率(トレーニング) = 0.17
#                 : 430. 正答率(テスト) = 0.2106
# Generation: 440. 正答率(トレーニング) = 0.13
#                 : 440. 正答率(テスト) = 0.2103
# Generation: 450. 正答率(トレーニング) = 0.22
#                 : 450. 正答率(テスト) = 0.2102
# Generation: 460. 正答率(トレーニング) = 0.19
#                 : 460. 正答率(テスト) = 0.2103
# Generation: 470. 正答率(トレーニング) = 0.21
#                 : 470. 正答率(テスト) = 0.217
# Generation: 480. 正答率(トレーニング) = 0.21
#                 : 480. 正答率(テスト) = 0.2204
# Generation: 490. 正答率(トレーニング) = 0.22
#                 : 490. 正答率(テスト) = 0.229
# Generation: 500. 正答率(トレーニング) = 0.15
#                 : 500. 正答率(テスト) = 0.2433
# Generation: 510. 正答率(トレーニング) = 0.26
#                 : 510. 正答率(テスト) = 0.2752
# Generation: 520. 正答率(トレーニング) = 0.32
#                 : 520. 正答率(テスト) = 0.2946
# Generation: 530. 正答率(トレーニング) = 0.39
#                 : 530. 正答率(テスト) = 0.2894
# Generation: 540. 正答率(トレーニング) = 0.39
#                 : 540. 正答率(テスト) = 0.342
# Generation: 550. 正答率(トレーニング) = 0.36
#                 : 550. 正答率(テスト) = 0.3125
# Generation: 560. 正答率(トレーニング) = 0.31
#                 : 560. 正答率(テスト) = 0.3013
# Generation: 570. 正答率(トレーニング) = 0.5
#                 : 570. 正答率(テスト) = 0.3013
# Generation: 580. 正答率(トレーニング) = 0.39
#                 : 580. 正答率(テスト) = 0.3395
# Generation: 590. 正答率(トレーニング) = 0.31
#                 : 590. 正答率(テスト) = 0.3326
# Generation: 600. 正答率(トレーニング) = 0.34
#                 : 600. 正答率(テスト) = 0.3638
# Generation: 610. 正答率(トレーニング) = 0.39
#                 : 610. 正答率(テスト) = 0.3786
# Generation: 620. 正答率(トレーニング) = 0.4
#                 : 620. 正答率(テスト) = 0.3251
# Generation: 630. 正答率(トレーニング) = 0.39
#                 : 630. 正答率(テスト) = 0.397
# Generation: 640. 正答率(トレーニング) = 0.49
#                 : 640. 正答率(テスト) = 0.3612
# Generation: 650. 正答率(トレーニング) = 0.45
#                 : 650. 正答率(テスト) = 0.3369
# Generation: 660. 正答率(トレーニング) = 0.4
#                 : 660. 正答率(テスト) = 0.3549
# Generation: 670. 正答率(トレーニング) = 0.36
#                 : 670. 正答率(テスト) = 0.3399
# Generation: 680. 正答率(トレーニング) = 0.42
#                 : 680. 正答率(テスト) = 0.3942
# Generation: 690. 正答率(トレーニング) = 0.46
#                 : 690. 正答率(テスト) = 0.4154
# Generation: 700. 正答率(トレーニング) = 0.51
#                 : 700. 正答率(テスト) = 0.3956
# Generation: 710. 正答率(トレーニング) = 0.56
#                 : 710. 正答率(テスト) = 0.4668
# Generation: 720. 正答率(トレーニング) = 0.43
#                 : 720. 正答率(テスト) = 0.48
# Generation: 730. 正答率(トレーニング) = 0.6
#                 : 730. 正答率(テスト) = 0.4301
# Generation: 740. 正答率(トレーニング) = 0.62
#                 : 740. 正答率(テスト) = 0.502
# Generation: 750. 正答率(トレーニング) = 0.64
#                 : 750. 正答率(テスト) = 0.5542
# Generation: 760. 正答率(トレーニング) = 0.68
#                 : 760. 正答率(テスト) = 0.5671
# Generation: 770. 正答率(トレーニング) = 0.6
#                 : 770. 正答率(テスト) = 0.5854
# Generation: 780. 正答率(トレーニング) = 0.65
#                 : 780. 正答率(テスト) = 0.5626
# Generation: 790. 正答率(トレーニング) = 0.68
#                 : 790. 正答率(テスト) = 0.6111
# Generation: 800. 正答率(トレーニング) = 0.69
#                 : 800. 正答率(テスト) = 0.6408
# Generation: 810. 正答率(トレーニング) = 0.66
#                 : 810. 正答率(テスト) = 0.6532
# Generation: 820. 正答率(トレーニング) = 0.68
#                 : 820. 正答率(テスト) = 0.6984
# Generation: 830. 正答率(トレーニング) = 0.6
#                 : 830. 正答率(テスト) = 0.6802
# Generation: 840. 正答率(トレーニング) = 0.76
#                 : 840. 正答率(テスト) = 0.7205
# Generation: 850. 正答率(トレーニング) = 0.72
#                 : 850. 正答率(テスト) = 0.6795
# Generation: 860. 正答率(トレーニング) = 0.74
#                 : 860. 正答率(テスト) = 0.7352
# Generation: 870. 正答率(トレーニング) = 0.76
#                 : 870. 正答率(テスト) = 0.7664
# Generation: 880. 正答率(トレーニング) = 0.8
#                 : 880. 正答率(テスト) = 0.7777
# Generation: 890. 正答率(トレーニング) = 0.85
#                 : 890. 正答率(テスト) = 0.7727
# Generation: 900. 正答率(トレーニング) = 0.81
#                 : 900. 正答率(テスト) = 0.7835
# Generation: 910. 正答率(トレーニング) = 0.84
#                 : 910. 正答率(テスト) = 0.7912
# Generation: 920. 正答率(トレーニング) = 0.82
#                 : 920. 正答率(テスト) = 0.7898
# Generation: 930. 正答率(トレーニング) = 0.85
#                 : 930. 正答率(テスト) = 0.804
# Generation: 940. 正答率(トレーニング) = 0.71
#                 : 940. 正答率(テスト) = 0.7103
# Generation: 950. 正答率(トレーニング) = 0.86
#                 : 950. 正答率(テスト) = 0.8009
# Generation: 960. 正答率(トレーニング) = 0.83
#                 : 960. 正答率(テスト) = 0.8001
# Generation: 970. 正答率(トレーニング) = 0.78
#                 : 970. 正答率(テスト) = 0.8069
# Generation: 980. 正答率(トレーニング) = 0.83
#                 : 980. 正答率(テスト) = 0.823
# Generation: 990. 正答率(トレーニング) = 0.84
#                 : 990. 正答率(テスト) = 0.816
# Generation: 1000. 正答率(トレーニング) = 0.88
#                 : 1000. 正答率(テスト) = 0.8174
# Generation: 1010. 正答率(トレーニング) = 0.76
#                 : 1010. 正答率(テスト) = 0.8062
# Generation: 1020. 正答率(トレーニング) = 0.86
#                 : 1020. 正答率(テスト) = 0.818
# Generation: 1030. 正答率(トレーニング) = 0.89
#                 : 1030. 正答率(テスト) = 0.83
# Generation: 1040. 正答率(トレーニング) = 0.93
#                 : 1040. 正答率(テスト) = 0.8352
# Generation: 1050. 正答率(トレーニング) = 0.83
#                 : 1050. 正答率(テスト) = 0.7885
# Generation: 1060. 正答率(トレーニング) = 0.82
#                 : 1060. 正答率(テスト) = 0.8302
# Generation: 1070. 正答率(トレーニング) = 0.85
#                 : 1070. 正答率(テスト) = 0.8067
# Generation: 1080. 正答率(トレーニング) = 0.84
#                 : 1080. 正答率(テスト) = 0.8404
# Generation: 1090. 正答率(トレーニング) = 0.92
#                 : 1090. 正答率(テスト) = 0.8313
# Generation: 1100. 正答率(トレーニング) = 0.83
#                 : 1100. 正答率(テスト) = 0.8409
# Generation: 1110. 正答率(トレーニング) = 0.84
#                 : 1110. 正答率(テスト) = 0.8469
# Generation: 1120. 正答率(トレーニング) = 0.83
#                 : 1120. 正答率(テスト) = 0.821
# Generation: 1130. 正答率(トレーニング) = 0.85
#                 : 1130. 正答率(テスト) = 0.8468
# Generation: 1140. 正答率(トレーニング) = 0.9
#                 : 1140. 正答率(テスト) = 0.8375
# Generation: 1150. 正答率(トレーニング) = 0.85
#                 : 1150. 正答率(テスト) = 0.8378
# Generation: 1160. 正答率(トレーニング) = 0.89
#                 : 1160. 正答率(テスト) = 0.8231
# Generation: 1170. 正答率(トレーニング) = 0.88
#                 : 1170. 正答率(テスト) = 0.8514
# Generation: 1180. 正答率(トレーニング) = 0.88
#                 : 1180. 正答率(テスト) = 0.849
# Generation: 1190. 正答率(トレーニング) = 0.9
#                 : 1190. 正答率(テスト) = 0.851
# Generation: 1200. 正答率(トレーニング) = 0.86
#                 : 1200. 正答率(テスト) = 0.8583
# Generation: 1210. 正答率(トレーニング) = 0.89
#                 : 1210. 正答率(テスト) = 0.8416
# Generation: 1220. 正答率(トレーニング) = 0.9
#                 : 1220. 正答率(テスト) = 0.8477
# Generation: 1230. 正答率(トレーニング) = 0.88
#                 : 1230. 正答率(テスト) = 0.8462
# Generation: 1240. 正答率(トレーニング) = 0.92
#                 : 1240. 正答率(テスト) = 0.8631
# Generation: 1250. 正答率(トレーニング) = 0.83
#                 : 1250. 正答率(テスト) = 0.8533
# Generation: 1260. 正答率(トレーニング) = 0.88
#                 : 1260. 正答率(テスト) = 0.8596
# Generation: 1270. 正答率(トレーニング) = 0.92
#                 : 1270. 正答率(テスト) = 0.8687
# Generation: 1280. 正答率(トレーニング) = 0.84
#                 : 1280. 正答率(テスト) = 0.8652
# Generation: 1290. 正答率(トレーニング) = 0.88
#                 : 1290. 正答率(テスト) = 0.8692
# Generation: 1300. 正答率(トレーニング) = 0.9
#                 : 1300. 正答率(テスト) = 0.8527
# Generation: 1310. 正答率(トレーニング) = 0.9
#                 : 1310. 正答率(テスト) = 0.8621
# Generation: 1320. 正答率(トレーニング) = 0.93
#                 : 1320. 正答率(テスト) = 0.8711
# Generation: 1330. 正答率(トレーニング) = 0.92
#                 : 1330. 正答率(テスト) = 0.8746
# Generation: 1340. 正答率(トレーニング) = 0.84
#                 : 1340. 正答率(テスト) = 0.8628
# Generation: 1350. 正答率(トレーニング) = 0.88
#                 : 1350. 正答率(テスト) = 0.8739
# Generation: 1360. 正答率(トレーニング) = 0.89
#                 : 1360. 正答率(テスト) = 0.8781
# Generation: 1370. 正答率(トレーニング) = 0.95
#                 : 1370. 正答率(テスト) = 0.879
# Generation: 1380. 正答率(トレーニング) = 0.93
#                 : 1380. 正答率(テスト) = 0.8858
# Generation: 1390. 正答率(トレーニング) = 0.89
#                 : 1390. 正答率(テスト) = 0.877
# Generation: 1400. 正答率(トレーニング) = 0.89
#                 : 1400. 正答率(テスト) = 0.8803
# Generation: 1410. 正答率(トレーニング) = 0.91
#                 : 1410. 正答率(テスト) = 0.8843
# Generation: 1420. 正答率(トレーニング) = 0.91
#                 : 1420. 正答率(テスト) = 0.8817
# Generation: 1430. 正答率(トレーニング) = 0.9
#                 : 1430. 正答率(テスト) = 0.8916
# Generation: 1440. 正答率(トレーニング) = 0.89
#                 : 1440. 正答率(テスト) = 0.879
# Generation: 1450. 正答率(トレーニング) = 0.89
#                 : 1450. 正答率(テスト) = 0.882
# Generation: 1460. 正答率(トレーニング) = 0.9
#                 : 1460. 正答率(テスト) = 0.8871
# Generation: 1470. 正答率(トレーニング) = 0.88
#                 : 1470. 正答率(テスト) = 0.8862
# Generation: 1480. 正答率(トレーニング) = 0.93
#                 : 1480. 正答率(テスト) = 0.8858
# Generation: 1490. 正答率(トレーニング) = 0.87
#                 : 1490. 正答率(テスト) = 0.8615
# Generation: 1500. 正答率(トレーニング) = 0.95
#                 : 1500. 正答率(テスト) = 0.8927
# Generation: 1510. 正答率(トレーニング) = 0.89
#                 : 1510. 正答率(テスト) = 0.8853
# Generation: 1520. 正答率(トレーニング) = 0.97
#                 : 1520. 正答率(テスト) = 0.8907
# Generation: 1530. 正答率(トレーニング) = 0.95
#                 : 1530. 正答率(テスト) = 0.8946
# Generation: 1540. 正答率(トレーニング) = 0.94
#                 : 1540. 正答率(テスト) = 0.8954
# Generation: 1550. 正答率(トレーニング) = 0.92
#                 : 1550. 正答率(テスト) = 0.8866
# Generation: 1560. 正答率(トレーニング) = 0.95
#                 : 1560. 正答率(テスト) = 0.8942
# Generation: 1570. 正答率(トレーニング) = 0.91
#                 : 1570. 正答率(テスト) = 0.8994
# Generation: 1580. 正答率(トレーニング) = 0.95
#                 : 1580. 正答率(テスト) = 0.8934
# Generation: 1590. 正答率(トレーニング) = 0.88
#                 : 1590. 正答率(テスト) = 0.8877
# Generation: 1600. 正答率(トレーニング) = 0.93
#                 : 1600. 正答率(テスト) = 0.8961
# Generation: 1610. 正答率(トレーニング) = 0.97
#                 : 1610. 正答率(テスト) = 0.9013
# Generation: 1620. 正答率(トレーニング) = 0.93
#                 : 1620. 正答率(テスト) = 0.9062
# Generation: 1630. 正答率(トレーニング) = 0.92
#                 : 1630. 正答率(テスト) = 0.9038
# Generation: 1640. 正答率(トレーニング) = 0.94
#                 : 1640. 正答率(テスト) = 0.885
# Generation: 1650. 正答率(トレーニング) = 0.94
#                 : 1650. 正答率(テスト) = 0.9061
# Generation: 1660. 正答率(トレーニング) = 0.89
#                 : 1660. 正答率(テスト) = 0.8956
# Generation: 1670. 正答率(トレーニング) = 0.97
#                 : 1670. 正答率(テスト) = 0.906
# Generation: 1680. 正答率(トレーニング) = 0.9
#                 : 1680. 正答率(テスト) = 0.9024
# Generation: 1690. 正答率(トレーニング) = 0.98
#                 : 1690. 正答率(テスト) = 0.9087
# Generation: 1700. 正答率(トレーニング) = 0.92
#                 : 1700. 正答率(テスト) = 0.9056
# Generation: 1710. 正答率(トレーニング) = 0.95
#                 : 1710. 正答率(テスト) = 0.8955
# Generation: 1720. 正答率(トレーニング) = 0.91
#                 : 1720. 正答率(テスト) = 0.8845
# Generation: 1730. 正答率(トレーニング) = 0.89
#                 : 1730. 正答率(テスト) = 0.9001
# Generation: 1740. 正答率(トレーニング) = 0.91
#                 : 1740. 正答率(テスト) = 0.9036
# Generation: 1750. 正答率(トレーニング) = 0.91
#                 : 1750. 正答率(テスト) = 0.9095
# Generation: 1760. 正答率(トレーニング) = 0.94
#                 : 1760. 正答率(テスト) = 0.9127
# Generation: 1770. 正答率(トレーニング) = 0.9
#                 : 1770. 正答率(テスト) = 0.9058
# Generation: 1780. 正答率(トレーニング) = 0.9
#                 : 1780. 正答率(テスト) = 0.9048
# Generation: 1790. 正答率(トレーニング) = 0.93
#                 : 1790. 正答率(テスト) = 0.9076
# Generation: 1800. 正答率(トレーニング) = 0.97
#                 : 1800. 正答率(テスト) = 0.9123
# Generation: 1810. 正答率(トレーニング) = 0.93
#                 : 1810. 正答率(テスト) = 0.9119
# Generation: 1820. 正答率(トレーニング) = 0.9
#                 : 1820. 正答率(テスト) = 0.9156
# Generation: 1830. 正答率(トレーニング) = 0.93
#                 : 1830. 正答率(テスト) = 0.905
# Generation: 1840. 正答率(トレーニング) = 0.95
#                 : 1840. 正答率(テスト) = 0.9163
# Generation: 1850. 正答率(トレーニング) = 0.95
#                 : 1850. 正答率(テスト) = 0.879
# Generation: 1860. 正答率(トレーニング) = 1.0
#                 : 1860. 正答率(テスト) = 0.9081
# Generation: 1870. 正答率(トレーニング) = 0.95
#                 : 1870. 正答率(テスト) = 0.9122
# Generation: 1880. 正答率(トレーニング) = 0.94
#                 : 1880. 正答率(テスト) = 0.9116
# Generation: 1890. 正答率(トレーニング) = 0.91
#                 : 1890. 正答率(テスト) = 0.915
# Generation: 1900. 正答率(トレーニング) = 0.97
#                 : 1900. 正答率(テスト) = 0.9165
# Generation: 1910. 正答率(トレーニング) = 0.95
#                 : 1910. 正答率(テスト) = 0.9136
# Generation: 1920. 正答率(トレーニング) = 0.94
#                 : 1920. 正答率(テスト) = 0.9125
# Generation: 1930. 正答率(トレーニング) = 0.93
#                 : 1930. 正答率(テスト) = 0.9125
# Generation: 1940. 正答率(トレーニング) = 0.93
#                 : 1940. 正答率(テスト) = 0.9112
# Generation: 1950. 正答率(トレーニング) = 0.97
#                 : 1950. 正答率(テスト) = 0.9123
# Generation: 1960. 正答率(トレーニング) = 0.96
#                 : 1960. 正答率(テスト) = 0.9171
# Generation: 1970. 正答率(トレーニング) = 0.95
#                 : 1970. 正答率(テスト) = 0.9182
# Generation: 1980. 正答率(トレーニング) = 0.89
#                 : 1980. 正答率(テスト) = 0.9147
# Generation: 1990. 正答率(トレーニング) = 0.93
#                 : 1990. 正答率(テスト) = 0.9205
# Generation: 2000. 正答率(トレーニング) = 0.93
#                 : 2000. 正答率(テスト) = 0.9166

# %% [markdown]
# ## sigmoid - Xavier

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std='Xavier')

iters_num = 2000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)
    
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.11
#                 : 10. 正答率(テスト) = 0.1484
# Generation: 20. 正答率(トレーニング) = 0.14
#                 : 20. 正答率(テスト) = 0.101
# Generation: 30. 正答率(トレーニング) = 0.11
#                 : 30. 正答率(テスト) = 0.1617
# Generation: 40. 正答率(トレーニング) = 0.18
#                 : 40. 正答率(テスト) = 0.2001
# Generation: 50. 正答率(トレーニング) = 0.13
#                 : 50. 正答率(テスト) = 0.1186
# Generation: 60. 正答率(トレーニング) = 0.26
#                 : 60. 正答率(テスト) = 0.2052
# Generation: 70. 正答率(トレーニング) = 0.39
#                 : 70. 正答率(テスト) = 0.4174
# Generation: 80. 正答率(トレーニング) = 0.31
#                 : 80. 正答率(テスト) = 0.3039
# Generation: 90. 正答率(トレーニング) = 0.19
#                 : 90. 正答率(テスト) = 0.1652
# Generation: 100. 正答率(トレーニング) = 0.22
#                 : 100. 正答率(テスト) = 0.2228
# Generation: 110. 正答率(トレーニング) = 0.26
#                 : 110. 正答率(テスト) = 0.2813
# Generation: 120. 正答率(トレーニング) = 0.25
#                 : 120. 正答率(テスト) = 0.2055
# Generation: 130. 正答率(トレーニング) = 0.3
#                 : 130. 正答率(テスト) = 0.2716
# Generation: 140. 正答率(トレーニング) = 0.22
#                 : 140. 正答率(テスト) = 0.2577
# Generation: 150. 正答率(トレーニング) = 0.39
#                 : 150. 正答率(テスト) = 0.3827
# Generation: 160. 正答率(トレーニング) = 0.33
#                 : 160. 正答率(テスト) = 0.3454
# Generation: 170. 正答率(トレーニング) = 0.36
#                 : 170. 正答率(テスト) = 0.3611
# Generation: 180. 正答率(トレーニング) = 0.47
#                 : 180. 正答率(テスト) = 0.4295
# Generation: 190. 正答率(トレーニング) = 0.38
#                 : 190. 正答率(テスト) = 0.4244
# Generation: 200. 正答率(トレーニング) = 0.42
#                 : 200. 正答率(テスト) = 0.4791
# Generation: 210. 正答率(トレーニング) = 0.53
#                 : 210. 正答率(テスト) = 0.4709
# Generation: 220. 正答率(トレーニング) = 0.47
#                 : 220. 正答率(テスト) = 0.525
# Generation: 230. 正答率(トレーニング) = 0.45
#                 : 230. 正答率(テスト) = 0.4424
# Generation: 240. 正答率(トレーニング) = 0.39
#                 : 240. 正答率(テスト) = 0.3855
# Generation: 250. 正答率(トレーニング) = 0.43
#                 : 250. 正答率(テスト) = 0.3927
# Generation: 260. 正答率(トレーニング) = 0.44
#                 : 260. 正答率(テスト) = 0.3683
# Generation: 270. 正答率(トレーニング) = 0.44
#                 : 270. 正答率(テスト) = 0.385
# Generation: 280. 正答率(トレーニング) = 0.47
#                 : 280. 正答率(テスト) = 0.4333
# Generation: 290. 正答率(トレーニング) = 0.47
#                 : 290. 正答率(テスト) = 0.4443
# Generation: 300. 正答率(トレーニング) = 0.42
#                 : 300. 正答率(テスト) = 0.4046
# Generation: 310. 正答率(トレーニング) = 0.52
#                 : 310. 正答率(テスト) = 0.4662
# Generation: 320. 正答率(トレーニング) = 0.53
#                 : 320. 正答率(テスト) = 0.4308
# Generation: 330. 正答率(トレーニング) = 0.43
#                 : 330. 正答率(テスト) = 0.4713
# Generation: 340. 正答率(トレーニング) = 0.38
#                 : 340. 正答率(テスト) = 0.4814
# Generation: 350. 正答率(トレーニング) = 0.48
#                 : 350. 正答率(テスト) = 0.4794
# Generation: 360. 正答率(トレーニング) = 0.57
#                 : 360. 正答率(テスト) = 0.4788
# Generation: 370. 正答率(トレーニング) = 0.5
#                 : 370. 正答率(テスト) = 0.4953
# Generation: 380. 正答率(トレーニング) = 0.53
#                 : 380. 正答率(テスト) = 0.4977
# Generation: 390. 正答率(トレーニング) = 0.58
#                 : 390. 正答率(テスト) = 0.5004
# Generation: 400. 正答率(トレーニング) = 0.5
#                 : 400. 正答率(テスト) = 0.515
# Generation: 410. 正答率(トレーニング) = 0.55
#                 : 410. 正答率(テスト) = 0.5253
# Generation: 420. 正答率(トレーニング) = 0.58
#                 : 420. 正答率(テスト) = 0.5232
# Generation: 430. 正答率(トレーニング) = 0.6
#                 : 430. 正答率(テスト) = 0.5537
# Generation: 440. 正答率(トレーニング) = 0.55
#                 : 440. 正答率(テスト) = 0.5469
# Generation: 450. 正答率(トレーニング) = 0.51
#                 : 450. 正答率(テスト) = 0.5645
# Generation: 460. 正答率(トレーニング) = 0.53
#                 : 460. 正答率(テスト) = 0.5584
# Generation: 470. 正答率(トレーニング) = 0.53
#                 : 470. 正答率(テスト) = 0.5655
# Generation: 480. 正答率(トレーニング) = 0.63
#                 : 480. 正答率(テスト) = 0.5885
# Generation: 490. 正答率(トレーニング) = 0.56
#                 : 490. 正答率(テスト) = 0.5773
# Generation: 500. 正答率(トレーニング) = 0.66
#                 : 500. 正答率(テスト) = 0.583
# Generation: 510. 正答率(トレーニング) = 0.61
#                 : 510. 正答率(テスト) = 0.6136
# Generation: 520. 正答率(トレーニング) = 0.57
#                 : 520. 正答率(テスト) = 0.5826
# Generation: 530. 正答率(トレーニング) = 0.52
#                 : 530. 正答率(テスト) = 0.5934
# Generation: 540. 正答率(トレーニング) = 0.64
#                 : 540. 正答率(テスト) = 0.6179
# Generation: 550. 正答率(トレーニング) = 0.54
#                 : 550. 正答率(テスト) = 0.6269
# Generation: 560. 正答率(トレーニング) = 0.62
#                 : 560. 正答率(テスト) = 0.623
# Generation: 570. 正答率(トレーニング) = 0.72
#                 : 570. 正答率(テスト) = 0.6249
# Generation: 580. 正答率(トレーニング) = 0.68
#                 : 580. 正答率(テスト) = 0.6375
# Generation: 590. 正答率(トレーニング) = 0.64
#                 : 590. 正答率(テスト) = 0.6505
# Generation: 600. 正答率(トレーニング) = 0.65
#                 : 600. 正答率(テスト) = 0.6543
# Generation: 610. 正答率(トレーニング) = 0.68
#                 : 610. 正答率(テスト) = 0.6493
# Generation: 620. 正答率(トレーニング) = 0.63
#                 : 620. 正答率(テスト) = 0.6674
# Generation: 630. 正答率(トレーニング) = 0.7
#                 : 630. 正答率(テスト) = 0.6581
# Generation: 640. 正答率(トレーニング) = 0.75
#                 : 640. 正答率(テスト) = 0.6578
# Generation: 650. 正答率(トレーニング) = 0.66
#                 : 650. 正答率(テスト) = 0.6724
# Generation: 660. 正答率(トレーニング) = 0.64
#                 : 660. 正答率(テスト) = 0.6703
# Generation: 670. 正答率(トレーニング) = 0.63
#                 : 670. 正答率(テスト) = 0.6741
# Generation: 680. 正答率(トレーニング) = 0.63
#                 : 680. 正答率(テスト) = 0.6898
# Generation: 690. 正答率(トレーニング) = 0.7
#                 : 690. 正答率(テスト) = 0.6964
# Generation: 700. 正答率(トレーニング) = 0.74
#                 : 700. 正答率(テスト) = 0.7028
# Generation: 710. 正答率(トレーニング) = 0.72
#                 : 710. 正答率(テスト) = 0.6954
# Generation: 720. 正答率(トレーニング) = 0.63
#                 : 720. 正答率(テスト) = 0.6974
# Generation: 730. 正答率(トレーニング) = 0.64
#                 : 730. 正答率(テスト) = 0.7094
# Generation: 740. 正答率(トレーニング) = 0.65
#                 : 740. 正答率(テスト) = 0.7105
# Generation: 750. 正答率(トレーニング) = 0.69
#                 : 750. 正答率(テスト) = 0.7077
# Generation: 760. 正答率(トレーニング) = 0.71
#                 : 760. 正答率(テスト) = 0.7007
# Generation: 770. 正答率(トレーニング) = 0.69
#                 : 770. 正答率(テスト) = 0.7154
# Generation: 780. 正答率(トレーニング) = 0.77
#                 : 780. 正答率(テスト) = 0.7264
# Generation: 790. 正答率(トレーニング) = 0.71
#                 : 790. 正答率(テスト) = 0.7297
# Generation: 800. 正答率(トレーニング) = 0.81
#                 : 800. 正答率(テスト) = 0.7206
# Generation: 810. 正答率(トレーニング) = 0.7
#                 : 810. 正答率(テスト) = 0.7342
# Generation: 820. 正答率(トレーニング) = 0.78
#                 : 820. 正答率(テスト) = 0.7331
# Generation: 830. 正答率(トレーニング) = 0.68
#                 : 830. 正答率(テスト) = 0.7339
# Generation: 840. 正答率(トレーニング) = 0.79
#                 : 840. 正答率(テスト) = 0.7429
# Generation: 850. 正答率(トレーニング) = 0.78
#                 : 850. 正答率(テスト) = 0.7484
# Generation: 860. 正答率(トレーニング) = 0.71
#                 : 860. 正答率(テスト) = 0.7432
# Generation: 870. 正答率(トレーニング) = 0.66
#                 : 870. 正答率(テスト) = 0.7481
# Generation: 880. 正答率(トレーニング) = 0.75
#                 : 880. 正答率(テスト) = 0.7477
# Generation: 890. 正答率(トレーニング) = 0.73
#                 : 890. 正答率(テスト) = 0.7454
# Generation: 900. 正答率(トレーニング) = 0.71
#                 : 900. 正答率(テスト) = 0.7523
# Generation: 910. 正答率(トレーニング) = 0.8
#                 : 910. 正答率(テスト) = 0.7511
# Generation: 920. 正答率(トレーニング) = 0.77
#                 : 920. 正答率(テスト) = 0.7655
# Generation: 930. 正答率(トレーニング) = 0.82
#                 : 930. 正答率(テスト) = 0.7586
# Generation: 940. 正答率(トレーニング) = 0.82
#                 : 940. 正答率(テスト) = 0.7619
# Generation: 950. 正答率(トレーニング) = 0.74
#                 : 950. 正答率(テスト) = 0.7612
# Generation: 960. 正答率(トレーニング) = 0.81
#                 : 960. 正答率(テスト) = 0.7697
# Generation: 970. 正答率(トレーニング) = 0.75
#                 : 970. 正答率(テスト) = 0.7771
# Generation: 980. 正答率(トレーニング) = 0.8
#                 : 980. 正答率(テスト) = 0.7814
# Generation: 990. 正答率(トレーニング) = 0.77
#                 : 990. 正答率(テスト) = 0.7797
# Generation: 1000. 正答率(トレーニング) = 0.8
#                 : 1000. 正答率(テスト) = 0.7784
# Generation: 1010. 正答率(トレーニング) = 0.87
#                 : 1010. 正答率(テスト) = 0.7815
# Generation: 1020. 正答率(トレーニング) = 0.75
#                 : 1020. 正答率(テスト) = 0.789
# Generation: 1030. 正答率(トレーニング) = 0.77
#                 : 1030. 正答率(テスト) = 0.786
# Generation: 1040. 正答率(トレーニング) = 0.85
#                 : 1040. 正答率(テスト) = 0.7918
# Generation: 1050. 正答率(トレーニング) = 0.77
#                 : 1050. 正答率(テスト) = 0.7949
# Generation: 1060. 正答率(トレーニング) = 0.81
#                 : 1060. 正答率(テスト) = 0.7991
# Generation: 1070. 正答率(トレーニング) = 0.79
#                 : 1070. 正答率(テスト) = 0.7964
# Generation: 1080. 正答率(トレーニング) = 0.82
#                 : 1080. 正答率(テスト) = 0.8037
# Generation: 1090. 正答率(トレーニング) = 0.82
#                 : 1090. 正答率(テスト) = 0.807
# Generation: 1100. 正答率(トレーニング) = 0.84
#                 : 1100. 正答率(テスト) = 0.8041
# Generation: 1110. 正答率(トレーニング) = 0.77
#                 : 1110. 正答率(テスト) = 0.8086
# Generation: 1120. 正答率(トレーニング) = 0.81
#                 : 1120. 正答率(テスト) = 0.8044
# Generation: 1130. 正答率(トレーニング) = 0.8
#                 : 1130. 正答率(テスト) = 0.8082
# Generation: 1140. 正答率(トレーニング) = 0.84
#                 : 1140. 正答率(テスト) = 0.8173
# Generation: 1150. 正答率(トレーニング) = 0.76
#                 : 1150. 正答率(テスト) = 0.8135
# Generation: 1160. 正答率(トレーニング) = 0.79
#                 : 1160. 正答率(テスト) = 0.8224
# Generation: 1170. 正答率(トレーニング) = 0.88
#                 : 1170. 正答率(テスト) = 0.8198
# Generation: 1180. 正答率(トレーニング) = 0.88
#                 : 1180. 正答率(テスト) = 0.8234
# Generation: 1190. 正答率(トレーニング) = 0.86
#                 : 1190. 正答率(テスト) = 0.8198
# Generation: 1200. 正答率(トレーニング) = 0.76
#                 : 1200. 正答率(テスト) = 0.8223
# Generation: 1210. 正答率(トレーニング) = 0.79
#                 : 1210. 正答率(テスト) = 0.8195
# Generation: 1220. 正答率(トレーニング) = 0.86
#                 : 1220. 正答率(テスト) = 0.8234
# Generation: 1230. 正答率(トレーニング) = 0.9
#                 : 1230. 正答率(テスト) = 0.8249
# Generation: 1240. 正答率(トレーニング) = 0.81
#                 : 1240. 正答率(テスト) = 0.8295
# Generation: 1250. 正答率(トレーニング) = 0.81
#                 : 1250. 正答率(テスト) = 0.8292
# Generation: 1260. 正答率(トレーニング) = 0.82
#                 : 1260. 正答率(テスト) = 0.8361
# Generation: 1270. 正答率(トレーニング) = 0.86
#                 : 1270. 正答率(テスト) = 0.8309
# Generation: 1280. 正答率(トレーニング) = 0.76
#                 : 1280. 正答率(テスト) = 0.836
# Generation: 1290. 正答率(トレーニング) = 0.84
#                 : 1290. 正答率(テスト) = 0.8364
# Generation: 1300. 正答率(トレーニング) = 0.86
#                 : 1300. 正答率(テスト) = 0.8376
# Generation: 1310. 正答率(トレーニング) = 0.83
#                 : 1310. 正答率(テスト) = 0.8396
# Generation: 1320. 正答率(トレーニング) = 0.85
#                 : 1320. 正答率(テスト) = 0.8388
# Generation: 1330. 正答率(トレーニング) = 0.84
#                 : 1330. 正答率(テスト) = 0.8436
# Generation: 1340. 正答率(トレーニング) = 0.82
#                 : 1340. 正答率(テスト) = 0.8463
# Generation: 1350. 正答率(トレーニング) = 0.89
#                 : 1350. 正答率(テスト) = 0.842
# Generation: 1360. 正答率(トレーニング) = 0.78
#                 : 1360. 正答率(テスト) = 0.8457
# Generation: 1370. 正答率(トレーニング) = 0.81
#                 : 1370. 正答率(テスト) = 0.8486
# Generation: 1380. 正答率(トレーニング) = 0.85
#                 : 1380. 正答率(テスト) = 0.8484
# Generation: 1390. 正答率(トレーニング) = 0.88
#                 : 1390. 正答率(テスト) = 0.8495
# Generation: 1400. 正答率(トレーニング) = 0.86
#                 : 1400. 正答率(テスト) = 0.8492
# Generation: 1410. 正答率(トレーニング) = 0.88
#                 : 1410. 正答率(テスト) = 0.8536
# Generation: 1420. 正答率(トレーニング) = 0.87
#                 : 1420. 正答率(テスト) = 0.8559
# Generation: 1430. 正答率(トレーニング) = 0.93
#                 : 1430. 正答率(テスト) = 0.8537
# Generation: 1440. 正答率(トレーニング) = 0.88
#                 : 1440. 正答率(テスト) = 0.8552
# Generation: 1450. 正答率(トレーニング) = 0.83
#                 : 1450. 正答率(テスト) = 0.8501
# Generation: 1460. 正答率(トレーニング) = 0.89
#                 : 1460. 正答率(テスト) = 0.8556
# Generation: 1470. 正答率(トレーニング) = 0.85
#                 : 1470. 正答率(テスト) = 0.8571
# Generation: 1480. 正答率(トレーニング) = 0.78
#                 : 1480. 正答率(テスト) = 0.858
# Generation: 1490. 正答率(トレーニング) = 0.84
#                 : 1490. 正答率(テスト) = 0.8599
# Generation: 1500. 正答率(トレーニング) = 0.79
#                 : 1500. 正答率(テスト) = 0.8584
# Generation: 1510. 正答率(トレーニング) = 0.86
#                 : 1510. 正答率(テスト) = 0.86
# Generation: 1520. 正答率(トレーニング) = 0.86
#                 : 1520. 正答率(テスト) = 0.8634
# Generation: 1530. 正答率(トレーニング) = 0.87
#                 : 1530. 正答率(テスト) = 0.8641
# Generation: 1540. 正答率(トレーニング) = 0.86
#                 : 1540. 正答率(テスト) = 0.8633
# Generation: 1550. 正答率(トレーニング) = 0.92
#                 : 1550. 正答率(テスト) = 0.8638
# Generation: 1560. 正答率(トレーニング) = 0.83
#                 : 1560. 正答率(テスト) = 0.8656
# Generation: 1570. 正答率(トレーニング) = 0.92
#                 : 1570. 正答率(テスト) = 0.8668
# Generation: 1580. 正答率(トレーニング) = 0.88
#                 : 1580. 正答率(テスト) = 0.8662
# Generation: 1590. 正答率(トレーニング) = 0.88
#                 : 1590. 正答率(テスト) = 0.8676
# Generation: 1600. 正答率(トレーニング) = 0.9
#                 : 1600. 正答率(テスト) = 0.8683
# Generation: 1610. 正答率(トレーニング) = 0.89
#                 : 1610. 正答率(テスト) = 0.8681
# Generation: 1620. 正答率(トレーニング) = 0.9
#                 : 1620. 正答率(テスト) = 0.8697
# Generation: 1630. 正答率(トレーニング) = 0.89
#                 : 1630. 正答率(テスト) = 0.8696
# Generation: 1640. 正答率(トレーニング) = 0.86
#                 : 1640. 正答率(テスト) = 0.8679
# Generation: 1650. 正答率(トレーニング) = 0.85
#                 : 1650. 正答率(テスト) = 0.8706
# Generation: 1660. 正答率(トレーニング) = 0.94
#                 : 1660. 正答率(テスト) = 0.8712
# Generation: 1670. 正答率(トレーニング) = 0.92
#                 : 1670. 正答率(テスト) = 0.8704
# Generation: 1680. 正答率(トレーニング) = 0.9
#                 : 1680. 正答率(テスト) = 0.8704
# Generation: 1690. 正答率(トレーニング) = 0.86
#                 : 1690. 正答率(テスト) = 0.8723
# Generation: 1700. 正答率(トレーニング) = 0.89
#                 : 1700. 正答率(テスト) = 0.873
# Generation: 1710. 正答率(トレーニング) = 0.87
#                 : 1710. 正答率(テスト) = 0.8731
# Generation: 1720. 正答率(トレーニング) = 0.82
#                 : 1720. 正答率(テスト) = 0.8718
# Generation: 1730. 正答率(トレーニング) = 0.87
#                 : 1730. 正答率(テスト) = 0.8755
# Generation: 1740. 正答率(トレーニング) = 0.87
#                 : 1740. 正答率(テスト) = 0.8757
# Generation: 1750. 正答率(トレーニング) = 0.92
#                 : 1750. 正答率(テスト) = 0.8754
# Generation: 1760. 正答率(トレーニング) = 0.82
#                 : 1760. 正答率(テスト) = 0.875
# Generation: 1770. 正答率(トレーニング) = 0.83
#                 : 1770. 正答率(テスト) = 0.875
# Generation: 1780. 正答率(トレーニング) = 0.86
#                 : 1780. 正答率(テスト) = 0.8767
# Generation: 1790. 正答率(トレーニング) = 0.92
#                 : 1790. 正答率(テスト) = 0.877
# Generation: 1800. 正答率(トレーニング) = 0.87
#                 : 1800. 正答率(テスト) = 0.8766
# Generation: 1810. 正答率(トレーニング) = 0.84
#                 : 1810. 正答率(テスト) = 0.8784
# Generation: 1820. 正答率(トレーニング) = 0.89
#                 : 1820. 正答率(テスト) = 0.8789
# Generation: 1830. 正答率(トレーニング) = 0.87
#                 : 1830. 正答率(テスト) = 0.8799
# Generation: 1840. 正答率(トレーニング) = 0.86
#                 : 1840. 正答率(テスト) = 0.8784
# Generation: 1850. 正答率(トレーニング) = 0.91
#                 : 1850. 正答率(テスト) = 0.8796
# Generation: 1860. 正答率(トレーニング) = 0.88
#                 : 1860. 正答率(テスト) = 0.8816
# Generation: 1870. 正答率(トレーニング) = 0.81
#                 : 1870. 正答率(テスト) = 0.8825
# Generation: 1880. 正答率(トレーニング) = 0.91
#                 : 1880. 正答率(テスト) = 0.8802
# Generation: 1890. 正答率(トレーニング) = 0.92
#                 : 1890. 正答率(テスト) = 0.8832
# Generation: 1900. 正答率(トレーニング) = 0.89
#                 : 1900. 正答率(テスト) = 0.8826
# Generation: 1910. 正答率(トレーニング) = 0.93
#                 : 1910. 正答率(テスト) = 0.8844
# Generation: 1920. 正答率(トレーニング) = 0.88
#                 : 1920. 正答率(テスト) = 0.8833
# Generation: 1930. 正答率(トレーニング) = 0.88
#                 : 1930. 正答率(テスト) = 0.884
# Generation: 1940. 正答率(トレーニング) = 0.84
#                 : 1940. 正答率(テスト) = 0.884
# Generation: 1950. 正答率(トレーニング) = 0.85
#                 : 1950. 正答率(テスト) = 0.8849
# Generation: 1960. 正答率(トレーニング) = 0.93
#                 : 1960. 正答率(テスト) = 0.8839
# Generation: 1970. 正答率(トレーニング) = 0.85
#                 : 1970. 正答率(テスト) = 0.8841
# Generation: 1980. 正答率(トレーニング) = 0.83
#                 : 1980. 正答率(テスト) = 0.8847
# Generation: 1990. 正答率(トレーニング) = 0.86
#                 : 1990. 正答率(テスト) = 0.8857
# Generation: 2000. 正答率(トレーニング) = 0.88
#                 : 2000. 正答率(テスト) = 0.8866

# %% [markdown]
# ## ReLU - He

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='relu', weight_init_std='He')

iters_num = 2000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)
    
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.54
#                 : 10. 正答率(テスト) = 0.4415
# Generation: 20. 正答率(トレーニング) = 0.67
#                 : 20. 正答率(テスト) = 0.5902
# Generation: 30. 正答率(トレーニング) = 0.78
#                 : 30. 正答率(テスト) = 0.7108
# Generation: 40. 正答率(トレーニング) = 0.77
#                 : 40. 正答率(テスト) = 0.7639
# Generation: 50. 正答率(トレーニング) = 0.8
#                 : 50. 正答率(テスト) = 0.8101
# Generation: 60. 正答率(トレーニング) = 0.88
#                 : 60. 正答率(テスト) = 0.8046
# Generation: 70. 正答率(トレーニング) = 0.86
#                 : 70. 正答率(テスト) = 0.8431
# Generation: 80. 正答率(トレーニング) = 0.91
#                 : 80. 正答率(テスト) = 0.8643
# Generation: 90. 正答率(トレーニング) = 0.89
#                 : 90. 正答率(テスト) = 0.8685
# Generation: 100. 正答率(トレーニング) = 0.9
#                 : 100. 正答率(テスト) = 0.867
# Generation: 110. 正答率(トレーニング) = 0.85
#                 : 110. 正答率(テスト) = 0.841
# Generation: 120. 正答率(トレーニング) = 0.91
#                 : 120. 正答率(テスト) = 0.8842
# Generation: 130. 正答率(トレーニング) = 0.87
#                 : 130. 正答率(テスト) = 0.8741
# Generation: 140. 正答率(トレーニング) = 0.88
#                 : 140. 正答率(テスト) = 0.8906
# Generation: 150. 正答率(トレーニング) = 0.89
#                 : 150. 正答率(テスト) = 0.8605
# Generation: 160. 正答率(トレーニング) = 0.94
#                 : 160. 正答率(テスト) = 0.8863
# Generation: 170. 正答率(トレーニング) = 0.9
#                 : 170. 正答率(テスト) = 0.8924
# Generation: 180. 正答率(トレーニング) = 0.94
#                 : 180. 正答率(テスト) = 0.8855
# Generation: 190. 正答率(トレーニング) = 0.89
#                 : 190. 正答率(テスト) = 0.848
# Generation: 200. 正答率(トレーニング) = 0.92
#                 : 200. 正答率(テスト) = 0.8927
# Generation: 210. 正答率(トレーニング) = 0.89
#                 : 210. 正答率(テスト) = 0.9027
# Generation: 220. 正答率(トレーニング) = 0.95
#                 : 220. 正答率(テスト) = 0.9006
# Generation: 230. 正答率(トレーニング) = 0.93
#                 : 230. 正答率(テスト) = 0.8994
# Generation: 240. 正答率(トレーニング) = 0.86
#                 : 240. 正答率(テスト) = 0.8995
# Generation: 250. 正答率(トレーニング) = 0.96
#                 : 250. 正答率(テスト) = 0.9074
# Generation: 260. 正答率(トレーニング) = 0.9
#                 : 260. 正答率(テスト) = 0.9012
# Generation: 270. 正答率(トレーニング) = 0.84
#                 : 270. 正答率(テスト) = 0.903
# Generation: 280. 正答率(トレーニング) = 0.94
#                 : 280. 正答率(テスト) = 0.91
# Generation: 290. 正答率(トレーニング) = 0.93
#                 : 290. 正答率(テスト) = 0.9151
# Generation: 300. 正答率(トレーニング) = 0.9
#                 : 300. 正答率(テスト) = 0.903
# Generation: 310. 正答率(トレーニング) = 0.93
#                 : 310. 正答率(テスト) = 0.8644
# Generation: 320. 正答率(トレーニング) = 0.88
#                 : 320. 正答率(テスト) = 0.908
# Generation: 330. 正答率(トレーニング) = 0.95
#                 : 330. 正答率(テスト) = 0.915
# Generation: 340. 正答率(トレーニング) = 0.95
#                 : 340. 正答率(テスト) = 0.9176
# Generation: 350. 正答率(トレーニング) = 0.97
#                 : 350. 正答率(テスト) = 0.9172
# Generation: 360. 正答率(トレーニング) = 0.89
#                 : 360. 正答率(テスト) = 0.912
# Generation: 370. 正答率(トレーニング) = 0.95
#                 : 370. 正答率(テスト) = 0.9169
# Generation: 380. 正答率(トレーニング) = 0.95
#                 : 380. 正答率(テスト) = 0.9166
# Generation: 390. 正答率(トレーニング) = 0.91
#                 : 390. 正答率(テスト) = 0.9111
# Generation: 400. 正答率(トレーニング) = 0.96
#                 : 400. 正答率(テスト) = 0.9053
# Generation: 410. 正答率(トレーニング) = 0.98
#                 : 410. 正答率(テスト) = 0.9203
# Generation: 420. 正答率(トレーニング) = 0.96
#                 : 420. 正答率(テスト) = 0.9228
# Generation: 430. 正答率(トレーニング) = 0.9
#                 : 430. 正答率(テスト) = 0.9164
# Generation: 440. 正答率(トレーニング) = 0.96
#                 : 440. 正答率(テスト) = 0.918
# Generation: 450. 正答率(トレーニング) = 0.97
#                 : 450. 正答率(テスト) = 0.9233
# Generation: 460. 正答率(トレーニング) = 0.93
#                 : 460. 正答率(テスト) = 0.9029
# Generation: 470. 正答率(トレーニング) = 0.97
#                 : 470. 正答率(テスト) = 0.9231
# Generation: 480. 正答率(トレーニング) = 0.99
#                 : 480. 正答率(テスト) = 0.9241
# Generation: 490. 正答率(トレーニング) = 0.94
#                 : 490. 正答率(テスト) = 0.9212
# Generation: 500. 正答率(トレーニング) = 0.93
#                 : 500. 正答率(テスト) = 0.9051
# Generation: 510. 正答率(トレーニング) = 0.92
#                 : 510. 正答率(テスト) = 0.9195
# Generation: 520. 正答率(トレーニング) = 0.95
#                 : 520. 正答率(テスト) = 0.9254
# Generation: 530. 正答率(トレーニング) = 0.97
#                 : 530. 正答率(テスト) = 0.9253
# Generation: 540. 正答率(トレーニング) = 0.96
#                 : 540. 正答率(テスト) = 0.9242
# Generation: 550. 正答率(トレーニング) = 0.97
#                 : 550. 正答率(テスト) = 0.9248
# Generation: 560. 正答率(トレーニング) = 0.95
#                 : 560. 正答率(テスト) = 0.9244
# Generation: 570. 正答率(トレーニング) = 0.94
#                 : 570. 正答率(テスト) = 0.9257
# Generation: 580. 正答率(トレーニング) = 0.95
#                 : 580. 正答率(テスト) = 0.9213
# Generation: 590. 正答率(トレーニング) = 0.9
#                 : 590. 正答率(テスト) = 0.9257
# Generation: 600. 正答率(トレーニング) = 0.9
#                 : 600. 正答率(テスト) = 0.9284
# Generation: 610. 正答率(トレーニング) = 0.97
#                 : 610. 正答率(テスト) = 0.9251
# Generation: 620. 正答率(トレーニング) = 0.99
#                 : 620. 正答率(テスト) = 0.9235
# Generation: 630. 正答率(トレーニング) = 0.96
#                 : 630. 正答率(テスト) = 0.9306
# Generation: 640. 正答率(トレーニング) = 0.97
#                 : 640. 正答率(テスト) = 0.9254
# Generation: 650. 正答率(トレーニング) = 0.95
#                 : 650. 正答率(テスト) = 0.9338
# Generation: 660. 正答率(トレーニング) = 0.98
#                 : 660. 正答率(テスト) = 0.9351
# Generation: 670. 正答率(トレーニング) = 0.97
#                 : 670. 正答率(テスト) = 0.9254
# Generation: 680. 正答率(トレーニング) = 0.96
#                 : 680. 正答率(テスト) = 0.9309
# Generation: 690. 正答率(トレーニング) = 0.95
#                 : 690. 正答率(テスト) = 0.9267
# Generation: 700. 正答率(トレーニング) = 0.97
#                 : 700. 正答率(テスト) = 0.9269
# Generation: 710. 正答率(トレーニング) = 0.96
#                 : 710. 正答率(テスト) = 0.9301
# Generation: 720. 正答率(トレーニング) = 0.92
#                 : 720. 正答率(テスト) = 0.9352
# Generation: 730. 正答率(トレーニング) = 0.95
#                 : 730. 正答率(テスト) = 0.9344
# Generation: 740. 正答率(トレーニング) = 0.97
#                 : 740. 正答率(テスト) = 0.9352
# Generation: 750. 正答率(トレーニング) = 0.96
#                 : 750. 正答率(テスト) = 0.9338
# Generation: 760. 正答率(トレーニング) = 0.95
#                 : 760. 正答率(テスト) = 0.9357
# Generation: 770. 正答率(トレーニング) = 0.95
#                 : 770. 正答率(テスト) = 0.9313
# Generation: 780. 正答率(トレーニング) = 0.97
#                 : 780. 正答率(テスト) = 0.9356
# Generation: 790. 正答率(トレーニング) = 0.97
#                 : 790. 正答率(テスト) = 0.9339
# Generation: 800. 正答率(トレーニング) = 0.95
#                 : 800. 正答率(テスト) = 0.9331
# Generation: 810. 正答率(トレーニング) = 0.96
#                 : 810. 正答率(テスト) = 0.935
# Generation: 820. 正答率(トレーニング) = 0.96
#                 : 820. 正答率(テスト) = 0.9261
# Generation: 830. 正答率(トレーニング) = 0.93
#                 : 830. 正答率(テスト) = 0.934
# Generation: 840. 正答率(トレーニング) = 0.96
#                 : 840. 正答率(テスト) = 0.9366
# Generation: 850. 正答率(トレーニング) = 0.97
#                 : 850. 正答率(テスト) = 0.9387
# Generation: 860. 正答率(トレーニング) = 0.97
#                 : 860. 正答率(テスト) = 0.9374
# Generation: 870. 正答率(トレーニング) = 0.99
#                 : 870. 正答率(テスト) = 0.9336
# Generation: 880. 正答率(トレーニング) = 0.97
#                 : 880. 正答率(テスト) = 0.9375
# Generation: 890. 正答率(トレーニング) = 0.99
#                 : 890. 正答率(テスト) = 0.9324
# Generation: 900. 正答率(トレーニング) = 0.96
#                 : 900. 正答率(テスト) = 0.9378
# Generation: 910. 正答率(トレーニング) = 0.98
#                 : 910. 正答率(テスト) = 0.9378
# Generation: 920. 正答率(トレーニング) = 0.94
#                 : 920. 正答率(テスト) = 0.9277
# Generation: 930. 正答率(トレーニング) = 0.96
#                 : 930. 正答率(テスト) = 0.9378
# Generation: 940. 正答率(トレーニング) = 0.95
#                 : 940. 正答率(テスト) = 0.9335
# Generation: 950. 正答率(トレーニング) = 0.98
#                 : 950. 正答率(テスト) = 0.9383
# Generation: 960. 正答率(トレーニング) = 0.98
#                 : 960. 正答率(テスト) = 0.9404
# Generation: 970. 正答率(トレーニング) = 0.96
#                 : 970. 正答率(テスト) = 0.9379
# Generation: 980. 正答率(トレーニング) = 0.96
#                 : 980. 正答率(テスト) = 0.9391
# Generation: 990. 正答率(トレーニング) = 0.97
#                 : 990. 正答率(テスト) = 0.9342
# Generation: 1000. 正答率(トレーニング) = 0.95
#                 : 1000. 正答率(テスト) = 0.939
# Generation: 1010. 正答率(トレーニング) = 0.94
#                 : 1010. 正答率(テスト) = 0.933
# Generation: 1020. 正答率(トレーニング) = 0.92
#                 : 1020. 正答率(テスト) = 0.9377
# Generation: 1030. 正答率(トレーニング) = 0.94
#                 : 1030. 正答率(テスト) = 0.9409
# Generation: 1040. 正答率(トレーニング) = 0.96
#                 : 1040. 正答率(テスト) = 0.9406
# Generation: 1050. 正答率(トレーニング) = 0.96
#                 : 1050. 正答率(テスト) = 0.9383
# Generation: 1060. 正答率(トレーニング) = 0.96
#                 : 1060. 正答率(テスト) = 0.9342
# Generation: 1070. 正答率(トレーニング) = 0.98
#                 : 1070. 正答率(テスト) = 0.9385
# Generation: 1080. 正答率(トレーニング) = 0.99
#                 : 1080. 正答率(テスト) = 0.9393
# Generation: 1090. 正答率(トレーニング) = 0.94
#                 : 1090. 正答率(テスト) = 0.9402
# Generation: 1100. 正答率(トレーニング) = 0.98
#                 : 1100. 正答率(テスト) = 0.9365
# Generation: 1110. 正答率(トレーニング) = 0.97
#                 : 1110. 正答率(テスト) = 0.9417
# Generation: 1120. 正答率(トレーニング) = 0.95
#                 : 1120. 正答率(テスト) = 0.9449
# Generation: 1130. 正答率(トレーニング) = 0.93
#                 : 1130. 正答率(テスト) = 0.9438
# Generation: 1140. 正答率(トレーニング) = 0.98
#                 : 1140. 正答率(テスト) = 0.9397
# Generation: 1150. 正答率(トレーニング) = 0.99
#                 : 1150. 正答率(テスト) = 0.9437
# Generation: 1160. 正答率(トレーニング) = 0.97
#                 : 1160. 正答率(テスト) = 0.9416
# Generation: 1170. 正答率(トレーニング) = 0.98
#                 : 1170. 正答率(テスト) = 0.943
# Generation: 1180. 正答率(トレーニング) = 0.98
#                 : 1180. 正答率(テスト) = 0.9441
# Generation: 1190. 正答率(トレーニング) = 0.95
#                 : 1190. 正答率(テスト) = 0.9442
# Generation: 1200. 正答率(トレーニング) = 0.99
#                 : 1200. 正答率(テスト) = 0.9434
# Generation: 1210. 正答率(トレーニング) = 0.93
#                 : 1210. 正答率(テスト) = 0.9451
# Generation: 1220. 正答率(トレーニング) = 0.98
#                 : 1220. 正答率(テスト) = 0.9432
# Generation: 1230. 正答率(トレーニング) = 0.98
#                 : 1230. 正答率(テスト) = 0.9451
# Generation: 1240. 正答率(トレーニング) = 1.0
#                 : 1240. 正答率(テスト) = 0.9452
# Generation: 1250. 正答率(トレーニング) = 0.98
#                 : 1250. 正答率(テスト) = 0.9446
# Generation: 1260. 正答率(トレーニング) = 0.98
#                 : 1260. 正答率(テスト) = 0.9407
# Generation: 1270. 正答率(トレーニング) = 0.95
#                 : 1270. 正答率(テスト) = 0.9449
# Generation: 1280. 正答率(トレーニング) = 0.98
#                 : 1280. 正答率(テスト) = 0.9453
# Generation: 1290. 正答率(トレーニング) = 0.99
#                 : 1290. 正答率(テスト) = 0.9449
# Generation: 1300. 正答率(トレーニング) = 0.94
#                 : 1300. 正答率(テスト) = 0.9437
# Generation: 1310. 正答率(トレーニング) = 0.98
#                 : 1310. 正答率(テスト) = 0.9478
# Generation: 1320. 正答率(トレーニング) = 0.98
#                 : 1320. 正答率(テスト) = 0.9473
# Generation: 1330. 正答率(トレーニング) = 1.0
#                 : 1330. 正答率(テスト) = 0.9432
# Generation: 1340. 正答率(トレーニング) = 0.97
#                 : 1340. 正答率(テスト) = 0.9478
# Generation: 1350. 正答率(トレーニング) = 0.98
#                 : 1350. 正答率(テスト) = 0.9465
# Generation: 1360. 正答率(トレーニング) = 0.96
#                 : 1360. 正答率(テスト) = 0.9497
# Generation: 1370. 正答率(トレーニング) = 0.99
#                 : 1370. 正答率(テスト) = 0.9432
# Generation: 1380. 正答率(トレーニング) = 0.95
#                 : 1380. 正答率(テスト) = 0.9482
# Generation: 1390. 正答率(トレーニング) = 0.98
#                 : 1390. 正答率(テスト) = 0.9474
# Generation: 1400. 正答率(トレーニング) = 0.97
#                 : 1400. 正答率(テスト) = 0.9481
# Generation: 1410. 正答率(トレーニング) = 0.98
#                 : 1410. 正答率(テスト) = 0.9423
# Generation: 1420. 正答率(トレーニング) = 0.95
#                 : 1420. 正答率(テスト) = 0.9463
# Generation: 1430. 正答率(トレーニング) = 0.98
#                 : 1430. 正答率(テスト) = 0.949
# Generation: 1440. 正答率(トレーニング) = 0.96
#                 : 1440. 正答率(テスト) = 0.9475
# Generation: 1450. 正答率(トレーニング) = 0.96
#                 : 1450. 正答率(テスト) = 0.9473
# Generation: 1460. 正答率(トレーニング) = 1.0
#                 : 1460. 正答率(テスト) = 0.9477
# Generation: 1470. 正答率(トレーニング) = 0.97
#                 : 1470. 正答率(テスト) = 0.9472
# Generation: 1480. 正答率(トレーニング) = 0.99
#                 : 1480. 正答率(テスト) = 0.9468
# Generation: 1490. 正答率(トレーニング) = 0.98
#                 : 1490. 正答率(テスト) = 0.9483
# Generation: 1500. 正答率(トレーニング) = 0.98
#                 : 1500. 正答率(テスト) = 0.9481
# Generation: 1510. 正答率(トレーニング) = 0.97
#                 : 1510. 正答率(テスト) = 0.9472
# Generation: 1520. 正答率(トレーニング) = 0.98
#                 : 1520. 正答率(テスト) = 0.9492
# Generation: 1530. 正答率(トレーニング) = 0.98
#                 : 1530. 正答率(テスト) = 0.9485
# Generation: 1540. 正答率(トレーニング) = 0.97
#                 : 1540. 正答率(テスト) = 0.9487
# Generation: 1550. 正答率(トレーニング) = 0.99
#                 : 1550. 正答率(テスト) = 0.9497
# Generation: 1560. 正答率(トレーニング) = 1.0
#                 : 1560. 正答率(テスト) = 0.9495
# Generation: 1570. 正答率(トレーニング) = 0.94
#                 : 1570. 正答率(テスト) = 0.9475
# Generation: 1580. 正答率(トレーニング) = 0.99
#                 : 1580. 正答率(テスト) = 0.9489
# Generation: 1590. 正答率(トレーニング) = 0.99
#                 : 1590. 正答率(テスト) = 0.9494
# Generation: 1600. 正答率(トレーニング) = 0.99
#                 : 1600. 正答率(テスト) = 0.948
# Generation: 1610. 正答率(トレーニング) = 0.99
#                 : 1610. 正答率(テスト) = 0.9491
# Generation: 1620. 正答率(トレーニング) = 0.97
#                 : 1620. 正答率(テスト) = 0.9511
# Generation: 1630. 正答率(トレーニング) = 0.95
#                 : 1630. 正答率(テスト) = 0.9499
# Generation: 1640. 正答率(トレーニング) = 0.99
#                 : 1640. 正答率(テスト) = 0.9495
# Generation: 1650. 正答率(トレーニング) = 0.99
#                 : 1650. 正答率(テスト) = 0.95
# Generation: 1660. 正答率(トレーニング) = 0.97
#                 : 1660. 正答率(テスト) = 0.9501
# Generation: 1670. 正答率(トレーニング) = 0.97
#                 : 1670. 正答率(テスト) = 0.949
# Generation: 1680. 正答率(トレーニング) = 0.91
#                 : 1680. 正答率(テスト) = 0.9505
# Generation: 1690. 正答率(トレーニング) = 0.97
#                 : 1690. 正答率(テスト) = 0.948
# Generation: 1700. 正答率(トレーニング) = 0.97
#                 : 1700. 正答率(テスト) = 0.9537
# Generation: 1710. 正答率(トレーニング) = 0.97
#                 : 1710. 正答率(テスト) = 0.9529
# Generation: 1720. 正答率(トレーニング) = 0.94
#                 : 1720. 正答率(テスト) = 0.9521
# Generation: 1730. 正答率(トレーニング) = 0.99
#                 : 1730. 正答率(テスト) = 0.9546
# Generation: 1740. 正答率(トレーニング) = 0.97
#                 : 1740. 正答率(テスト) = 0.951
# Generation: 1750. 正答率(トレーニング) = 0.96
#                 : 1750. 正答率(テスト) = 0.9509
# Generation: 1760. 正答率(トレーニング) = 0.95
#                 : 1760. 正答率(テスト) = 0.9534
# Generation: 1770. 正答率(トレーニング) = 0.99
#                 : 1770. 正答率(テスト) = 0.955
# Generation: 1780. 正答率(トレーニング) = 0.94
#                 : 1780. 正答率(テスト) = 0.9536
# Generation: 1790. 正答率(トレーニング) = 1.0
#                 : 1790. 正答率(テスト) = 0.951
# Generation: 1800. 正答率(トレーニング) = 0.99
#                 : 1800. 正答率(テスト) = 0.9513
# Generation: 1810. 正答率(トレーニング) = 0.99
#                 : 1810. 正答率(テスト) = 0.9527
# Generation: 1820. 正答率(トレーニング) = 0.95
#                 : 1820. 正答率(テスト) = 0.9516
# Generation: 1830. 正答率(トレーニング) = 0.99
#                 : 1830. 正答率(テスト) = 0.9549
# Generation: 1840. 正答率(トレーニング) = 0.96
#                 : 1840. 正答率(テスト) = 0.9537
# Generation: 1850. 正答率(トレーニング) = 0.96
#                 : 1850. 正答率(テスト) = 0.9514
# Generation: 1860. 正答率(トレーニング) = 0.99
#                 : 1860. 正答率(テスト) = 0.9508
# Generation: 1870. 正答率(トレーニング) = 0.99
#                 : 1870. 正答率(テスト) = 0.9552
# Generation: 1880. 正答率(トレーニング) = 0.98
#                 : 1880. 正答率(テスト) = 0.9532
# Generation: 1890. 正答率(トレーニング) = 1.0
#                 : 1890. 正答率(テスト) = 0.9552
# Generation: 1900. 正答率(トレーニング) = 0.99
#                 : 1900. 正答率(テスト) = 0.9522
# Generation: 1910. 正答率(トレーニング) = 0.96
#                 : 1910. 正答率(テスト) = 0.9475
# Generation: 1920. 正答率(トレーニング) = 0.97
#                 : 1920. 正答率(テスト) = 0.9529
# Generation: 1930. 正答率(トレーニング) = 1.0
#                 : 1930. 正答率(テスト) = 0.9553
# Generation: 1940. 正答率(トレーニング) = 0.99
#                 : 1940. 正答率(テスト) = 0.9535
# Generation: 1950. 正答率(トレーニング) = 0.97
#                 : 1950. 正答率(テスト) = 0.9556
# Generation: 1960. 正答率(トレーニング) = 0.95
#                 : 1960. 正答率(テスト) = 0.9536
# Generation: 1970. 正答率(トレーニング) = 1.0
#                 : 1970. 正答率(テスト) = 0.9546
# Generation: 1980. 正答率(トレーニング) = 0.99
#                 : 1980. 正答率(テスト) = 0.9508
# Generation: 1990. 正答率(トレーニング) = 0.98
#                 : 1990. 正答率(テスト) = 0.9518
# Generation: 2000. 正答率(トレーニング) = 1.0
#                 : 2000. 正答率(テスト) = 0.9549

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## [try] hidden_size_listの数字を変更してみよう

# %% [markdown]
# ## [try] sigmoid - He と relu - Xavier についても試してみよう
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
