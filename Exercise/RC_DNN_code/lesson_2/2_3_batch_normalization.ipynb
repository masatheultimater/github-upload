# %% [markdown]
# # batch normalization

# %%
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
from collections import OrderedDict
from common import layers
from data.mnist import load_mnist
import matplotlib.pyplot as plt
from multi_layer_net import MultiLayerNet
from common import optimizer

# バッチ正則化 layer
class BatchNormalization:
    '''
    gamma: スケール係数
    beta: オフセット
    momentum: 慣性
    running_mean: テスト時に使用する平均
    running_var: テスト時に使用する分散
    '''
    def __init__(self, gamma, beta, momentum=0.9, running_mean=None, running_var=None):
        self.gamma = gamma
        self.beta = beta
        self.momentum = momentum
        self.input_shape = None

        self.running_mean = running_mean
        self.running_var = running_var  
        
        # backward時に使用する中間データ
        self.batch_size = None
        self.xc = None
        self.std = None
        self.dgamma = None
        self.dbeta = None

    def forward(self, x, train_flg=True):
        if self.running_mean is None:
            N, D = x.shape
            self.running_mean = np.zeros(D)
            self.running_var = np.zeros(D)
                        
        if train_flg:
            mu = x.mean(axis=0) # 平均
            xc = x - mu # xをセンタリング
            var = np.mean(xc**2, axis=0) # 分散
            std = np.sqrt(var + 10e-7) # スケーリング
            xn = xc / std
            
            self.batch_size = x.shape[0]
            self.xc = xc
            self.xn = xn
            self.std = std
            self.running_mean = self.momentum * self.running_mean + (1-self.momentum) * mu # 平均値の加重平均
            self.running_var = self.momentum * self.running_var + (1-self.momentum) * var #分散値の加重平均
        else:
            xc = x - self.running_mean
            xn = xc / ((np.sqrt(self.running_var + 10e-7)))
            
        out = self.gamma * xn + self.beta 
        
        return out

    def backward(self, dout):
        dbeta = dout.sum(axis=0)
        dgamma = np.sum(self.xn * dout, axis=0)
        dxn = self.gamma * dout
        dxc = dxn / self.std
        dstd = -np.sum((dxn * self.xc) / (self.std * self.std), axis=0)
        dvar = 0.5 * dstd / self.std
        dxc += (2.0 / self.batch_size) * self.xc * dvar
        dmu = np.sum(dxc, axis=0)
        dx = dxc - dmu / self.batch_size
        
        self.dgamma = dgamma
        self.dbeta = dbeta

        return dx

# %%
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")


# batch_normalizationの設定 =======================
use_batchnorm = True
# use_batchnorm = False
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10,
                        activation='sigmoid', weight_init_std='Xavier', use_batchnorm=use_batchnorm)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate=0.01

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10


for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]

        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)        
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
                

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.14
#                 : 10. 正答率(テスト) = 0.113
# Generation: 20. 正答率(トレーニング) = 0.2
#                 : 20. 正答率(テスト) = 0.1742
# Generation: 30. 正答率(トレーニング) = 0.28
#                 : 30. 正答率(テスト) = 0.2333
# Generation: 40. 正答率(トレーニング) = 0.31
#                 : 40. 正答率(テスト) = 0.2763
# Generation: 50. 正答率(トレーニング) = 0.29
#                 : 50. 正答率(テスト) = 0.3249
# Generation: 60. 正答率(トレーニング) = 0.31
#                 : 60. 正答率(テスト) = 0.3645
# Generation: 70. 正答率(トレーニング) = 0.36
#                 : 70. 正答率(テスト) = 0.3932
# Generation: 80. 正答率(トレーニング) = 0.36
#                 : 80. 正答率(テスト) = 0.4124
# Generation: 90. 正答率(トレーニング) = 0.42
#                 : 90. 正答率(テスト) = 0.4335
# Generation: 100. 正答率(トレーニング) = 0.45
#                 : 100. 正答率(テスト) = 0.449
# Generation: 110. 正答率(トレーニング) = 0.51
#                 : 110. 正答率(テスト) = 0.4582
# Generation: 120. 正答率(トレーニング) = 0.42
#                 : 120. 正答率(テスト) = 0.47
# Generation: 130. 正答率(トレーニング) = 0.45
#                 : 130. 正答率(テスト) = 0.4823
# Generation: 140. 正答率(トレーニング) = 0.49
#                 : 140. 正答率(テスト) = 0.4971
# Generation: 150. 正答率(トレーニング) = 0.41
#                 : 150. 正答率(テスト) = 0.5104
# Generation: 160. 正答率(トレーニング) = 0.5
#                 : 160. 正答率(テスト) = 0.5177
# Generation: 170. 正答率(トレーニング) = 0.5
#                 : 170. 正答率(テスト) = 0.5267
# Generation: 180. 正答率(トレーニング) = 0.45
#                 : 180. 正答率(テスト) = 0.5413
# Generation: 190. 正答率(トレーニング) = 0.54
#                 : 190. 正答率(テスト) = 0.5532
# Generation: 200. 正答率(トレーニング) = 0.56
#                 : 200. 正答率(テスト) = 0.5617
# Generation: 210. 正答率(トレーニング) = 0.54
#                 : 210. 正答率(テスト) = 0.5734
# Generation: 220. 正答率(トレーニング) = 0.59
#                 : 220. 正答率(テスト) = 0.5862
# Generation: 230. 正答率(トレーニング) = 0.6
#                 : 230. 正答率(テスト) = 0.5934
# Generation: 240. 正答率(トレーニング) = 0.59
#                 : 240. 正答率(テスト) = 0.6048
# Generation: 250. 正答率(トレーニング) = 0.59
#                 : 250. 正答率(テスト) = 0.6074
# Generation: 260. 正答率(トレーニング) = 0.58
#                 : 260. 正答率(テスト) = 0.6197
# Generation: 270. 正答率(トレーニング) = 0.64
#                 : 270. 正答率(テスト) = 0.6265
# Generation: 280. 正答率(トレーニング) = 0.61
#                 : 280. 正答率(テスト) = 0.6333
# Generation: 290. 正答率(トレーニング) = 0.63
#                 : 290. 正答率(テスト) = 0.6346
# Generation: 300. 正答率(トレーニング) = 0.63
#                 : 300. 正答率(テスト) = 0.6478
# Generation: 310. 正答率(トレーニング) = 0.68
#                 : 310. 正答率(テスト) = 0.6548
# Generation: 320. 正答率(トレーニング) = 0.59
#                 : 320. 正答率(テスト) = 0.6592
# Generation: 330. 正答率(トレーニング) = 0.67
#                 : 330. 正答率(テスト) = 0.6629
# Generation: 340. 正答率(トレーニング) = 0.6
#                 : 340. 正答率(テスト) = 0.6679
# Generation: 350. 正答率(トレーニング) = 0.64
#                 : 350. 正答率(テスト) = 0.6705
# Generation: 360. 正答率(トレーニング) = 0.71
#                 : 360. 正答率(テスト) = 0.6737
# Generation: 370. 正答率(トレーニング) = 0.69
#                 : 370. 正答率(テスト) = 0.6778
# Generation: 380. 正答率(トレーニング) = 0.67
#                 : 380. 正答率(テスト) = 0.6842
# Generation: 390. 正答率(トレーニング) = 0.67
#                 : 390. 正答率(テスト) = 0.6843
# Generation: 400. 正答率(トレーニング) = 0.66
#                 : 400. 正答率(テスト) = 0.6869
# Generation: 410. 正答率(トレーニング) = 0.72
#                 : 410. 正答率(テスト) = 0.6923
# Generation: 420. 正答率(トレーニング) = 0.64
#                 : 420. 正答率(テスト) = 0.6966
# Generation: 430. 正答率(トレーニング) = 0.68
#                 : 430. 正答率(テスト) = 0.7042
# Generation: 440. 正答率(トレーニング) = 0.7
#                 : 440. 正答率(テスト) = 0.7031
# Generation: 450. 正答率(トレーニング) = 0.75
#                 : 450. 正答率(テスト) = 0.7083
# Generation: 460. 正答率(トレーニング) = 0.77
#                 : 460. 正答率(テスト) = 0.7051
# Generation: 470. 正答率(トレーニング) = 0.73
#                 : 470. 正答率(テスト) = 0.7105
# Generation: 480. 正答率(トレーニング) = 0.78
#                 : 480. 正答率(テスト) = 0.7151
# Generation: 490. 正答率(トレーニング) = 0.66
#                 : 490. 正答率(テスト) = 0.7174
# Generation: 500. 正答率(トレーニング) = 0.68
#                 : 500. 正答率(テスト) = 0.7235
# Generation: 510. 正答率(トレーニング) = 0.69
#                 : 510. 正答率(テスト) = 0.7243
# Generation: 520. 正答率(トレーニング) = 0.71
#                 : 520. 正答率(テスト) = 0.7269
# Generation: 530. 正答率(トレーニング) = 0.71
#                 : 530. 正答率(テスト) = 0.7314
# Generation: 540. 正答率(トレーニング) = 0.71
#                 : 540. 正答率(テスト) = 0.7378
# Generation: 550. 正答率(トレーニング) = 0.75
#                 : 550. 正答率(テスト) = 0.7347
# Generation: 560. 正答率(トレーニング) = 0.77
#                 : 560. 正答率(テスト) = 0.7362
# Generation: 570. 正答率(トレーニング) = 0.78
#                 : 570. 正答率(テスト) = 0.7371
# Generation: 580. 正答率(トレーニング) = 0.67
#                 : 580. 正答率(テスト) = 0.7362
# Generation: 590. 正答率(トレーニング) = 0.74
#                 : 590. 正答率(テスト) = 0.7412
# Generation: 600. 正答率(トレーニング) = 0.76
#                 : 600. 正答率(テスト) = 0.7419
# Generation: 610. 正答率(トレーニング) = 0.69
#                 : 610. 正答率(テスト) = 0.7449
# Generation: 620. 正答率(トレーニング) = 0.71
#                 : 620. 正答率(テスト) = 0.7463
# Generation: 630. 正答率(トレーニング) = 0.76
#                 : 630. 正答率(テスト) = 0.7456
# Generation: 640. 正答率(トレーニング) = 0.73
#                 : 640. 正答率(テスト) = 0.7461
# Generation: 650. 正答率(トレーニング) = 0.76
#                 : 650. 正答率(テスト) = 0.7507
# Generation: 660. 正答率(トレーニング) = 0.78
#                 : 660. 正答率(テスト) = 0.7536
# Generation: 670. 正答率(トレーニング) = 0.74
#                 : 670. 正答率(テスト) = 0.7547
# Generation: 680. 正答率(トレーニング) = 0.73
#                 : 680. 正答率(テスト) = 0.7598
# Generation: 690. 正答率(トレーニング) = 0.66
#                 : 690. 正答率(テスト) = 0.762
# Generation: 700. 正答率(トレーニング) = 0.81
#                 : 700. 正答率(テスト) = 0.762
# Generation: 710. 正答率(トレーニング) = 0.8
#                 : 710. 正答率(テスト) = 0.7657
# Generation: 720. 正答率(トレーニング) = 0.75
#                 : 720. 正答率(テスト) = 0.7703
# Generation: 730. 正答率(トレーニング) = 0.76
#                 : 730. 正答率(テスト) = 0.7719
# Generation: 740. 正答率(トレーニング) = 0.75
#                 : 740. 正答率(テスト) = 0.7662
# Generation: 750. 正答率(トレーニング) = 0.84
#                 : 750. 正答率(テスト) = 0.7689
# Generation: 760. 正答率(トレーニング) = 0.85
#                 : 760. 正答率(テスト) = 0.7705
# Generation: 770. 正答率(トレーニング) = 0.77
#                 : 770. 正答率(テスト) = 0.7724
# Generation: 780. 正答率(トレーニング) = 0.8
#                 : 780. 正答率(テスト) = 0.7753
# Generation: 790. 正答率(トレーニング) = 0.81
#                 : 790. 正答率(テスト) = 0.7767
# Generation: 800. 正答率(トレーニング) = 0.84
#                 : 800. 正答率(テスト) = 0.7767
# Generation: 810. 正答率(トレーニング) = 0.74
#                 : 810. 正答率(テスト) = 0.7761
# Generation: 820. 正答率(トレーニング) = 0.84
#                 : 820. 正答率(テスト) = 0.7747
# Generation: 830. 正答率(トレーニング) = 0.78
#                 : 830. 正答率(テスト) = 0.7745
# Generation: 840. 正答率(トレーニング) = 0.74
#                 : 840. 正答率(テスト) = 0.7776
# Generation: 850. 正答率(トレーニング) = 0.76
#                 : 850. 正答率(テスト) = 0.7821
# Generation: 860. 正答率(トレーニング) = 0.84
#                 : 860. 正答率(テスト) = 0.7784
# Generation: 870. 正答率(トレーニング) = 0.73
#                 : 870. 正答率(テスト) = 0.779
# Generation: 880. 正答率(トレーニング) = 0.8
#                 : 880. 正答率(テスト) = 0.7813
# Generation: 890. 正答率(トレーニング) = 0.71
#                 : 890. 正答率(テスト) = 0.7808
# Generation: 900. 正答率(トレーニング) = 0.8
#                 : 900. 正答率(テスト) = 0.7788
# Generation: 910. 正答率(トレーニング) = 0.81
#                 : 910. 正答率(テスト) = 0.784
# Generation: 920. 正答率(トレーニング) = 0.79
#                 : 920. 正答率(テスト) = 0.7866
# Generation: 930. 正答率(トレーニング) = 0.71
#                 : 930. 正答率(テスト) = 0.786
# Generation: 940. 正答率(トレーニング) = 0.76
#                 : 940. 正答率(テスト) = 0.7875
# Generation: 950. 正答率(トレーニング) = 0.68
#                 : 950. 正答率(テスト) = 0.7923
# Generation: 960. 正答率(トレーニング) = 0.83
#                 : 960. 正答率(テスト) = 0.7896
# Generation: 970. 正答率(トレーニング) = 0.8
#                 : 970. 正答率(テスト) = 0.791
# Generation: 980. 正答率(トレーニング) = 0.79
#                 : 980. 正答率(テスト) = 0.7925
# Generation: 990. 正答率(トレーニング) = 0.85
#                 : 990. 正答率(テスト) = 0.7924
# Generation: 1000. 正答率(トレーニング) = 0.81
#                 : 1000. 正答率(テスト) = 0.7958

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## [try] 活性化関数や重みの初期値を変えてみよう
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
