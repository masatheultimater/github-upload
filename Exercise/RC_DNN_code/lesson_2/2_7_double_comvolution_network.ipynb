# %% [markdown]
# # double_comvolution_network

# %%
import sys, os
sys.path.append(os.pardir)
import pickle
import numpy as np
from collections import OrderedDict
from common import layers
from common import optimizer
from data.mnist import load_mnist
import matplotlib.pyplot as plt

class DoubleConvNet:
    # conv - relu - pool - conv - relu - pool - affine - relu - affine - softmax
    def __init__(self, input_dim=(1, 28, 28),
                 conv_param_1={'filter_num':10, 'filter_size':7, 'pad':1, 'stride':1},
                 conv_param_2={'filter_num':20, 'filter_size':3, 'pad':1, 'stride':1},
                 hidden_size=100, output_size=10, weight_init_std=0.01):
        conv_output_size_1 = (input_dim[1] - conv_param_1['filter_size'] + 2 * conv_param_1['pad']) / conv_param_1['stride'] + 1
        conv_output_size_2 = (conv_output_size_1 / 2 - conv_param_2['filter_size'] + 2 * conv_param_2['pad']) / conv_param_2['stride'] + 1        
        pool_output_size = int(conv_param_2['filter_num'] * (conv_output_size_2 / 2) * (conv_output_size_2 / 2))        
        # 重みの初期化
        self.params = {}
        self.params['W1'] = weight_init_std * np.random.randn(conv_param_1['filter_num'], input_dim[0], conv_param_1['filter_size'], conv_param_1['filter_size'])
        self.params['b1'] = np.zeros(conv_param_1['filter_num'])
        self.params['W2'] = weight_init_std * np.random.randn(conv_param_2['filter_num'], conv_param_1['filter_num'], conv_param_2['filter_size'], conv_param_2['filter_size'])
        self.params['b2'] = np.zeros(conv_param_2['filter_num'])
        self.params['W3'] = weight_init_std * np.random.randn(pool_output_size, hidden_size)
        self.params['b3'] = np.zeros(hidden_size)
        self.params['W4'] = weight_init_std * np.random.randn(hidden_size, output_size)
        self.params['b4'] = np.zeros(output_size)
        # レイヤの生成
        self.layers = OrderedDict()
        self.layers['Conv1'] = layers.Convolution(self.params['W1'], self.params['b1'], conv_param_1['stride'], conv_param_1['pad'])
        self.layers['Relu1'] = layers.Relu()
        self.layers['Pool1'] = layers.Pooling(pool_h=2, pool_w=2, stride=2)
        self.layers['Conv2'] = layers.Convolution(self.params['W2'], self.params['b2'], conv_param_2['stride'], conv_param_2['pad'])
        self.layers['Relu2'] = layers.Relu()
        self.layers['Pool2'] = layers.Pooling(pool_h=2, pool_w=2, stride=2)
        self.layers['Affine1'] = layers.Affine(self.params['W3'], self.params['b3'])
        self.layers['Relu3'] = layers.Relu()
        self.layers['Affine2'] = layers.Affine(self.params['W4'], self.params['b4'])
        self.last_layer = layers.SoftmaxWithLoss()

    def predict(self, x):
        for key in self.layers.keys():
            x = self.layers[key].forward(x)
        return x
        
    def loss(self, x, d):
        y = self.predict(x)
        return self.last_layer.forward(y, d)

    def accuracy(self, x, d, batch_size=100):
        if d.ndim != 1 : d = np.argmax(d, axis=1)
        
        acc = 0.0
        
        for i in range(int(x.shape[0] / batch_size)):
            tx = x[i*batch_size:(i+1)*batch_size]
            td = d[i*batch_size:(i+1)*batch_size]
            y = self.predict(tx)
            y = np.argmax(y, axis=1)
            acc += np.sum(y == td) 
        
        return acc / x.shape[0]

    def gradient(self, x, d):
        # forward
        self.loss(x, d)
        
        # backward
        dout = 1
        dout = self.last_layer.backward(dout)
        layers = list(self.layers.values())
        
        layers.reverse()
        for layer in layers:
            dout = layer.backward(dout)

        # 設定
        grad = {}
        grad['W1'], grad['b1'] = self.layers['Conv1'].dW, self.layers['Conv1'].db
        grad['W2'], grad['b2'] = self.layers['Conv2'].dW, self.layers['Conv2'].db        
        grad['W3'], grad['b3'] = self.layers['Affine1'].dW, self.layers['Affine1'].db
        grad['W4'], grad['b4'] = self.layers['Affine2'].dW, self.layers['Affine2'].db

        return grad

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(flatten=False)

print("データ読み込み完了")
# 処理に時間のかかる場合はデータを削減 
x_train, d_train = x_train[:5000], d_train[:5000]
x_test, d_test = x_test[:1000], d_test[:1000]


network = DoubleConvNet(input_dim=(1,28,28), 
                          conv_param_1={'filter_num':10, 'filter_size':7, 'pad':1, 'stride':1},
                          conv_param_2={'filter_num':20, 'filter_size':3, 'pad':1, 'stride':1},
                          hidden_size=100, output_size=10, weight_init_std=0.01)

optimizer = optimizer.Adam()

# 時間がかかるため100に設定
iters_num = 100
# iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10



for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]
    
    grad = network.gradient(x_batch, d_batch)
    optimizer.update(network.params, grad)
    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)

    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))               

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.149
#                 : 10. 正答率(テスト) = 0.211
# Generation: 20. 正答率(トレーニング) = 0.2412
#                 : 20. 正答率(テスト) = 0.28
# Generation: 30. 正答率(トレーニング) = 0.4634
#                 : 30. 正答率(テスト) = 0.454
# Generation: 40. 正答率(トレーニング) = 0.5824
#                 : 40. 正答率(テスト) = 0.567
# Generation: 50. 正答率(トレーニング) = 0.6162
#                 : 50. 正答率(テスト) = 0.593
# Generation: 60. 正答率(トレーニング) = 0.6964
#                 : 60. 正答率(テスト) = 0.657
# Generation: 70. 正答率(トレーニング) = 0.7366
#                 : 70. 正答率(テスト) = 0.707
# Generation: 80. 正答率(トレーニング) = 0.7652
#                 : 80. 正答率(テスト) = 0.721
# Generation: 90. 正答率(トレーニング) = 0.7822
#                 : 90. 正答率(テスト) = 0.764
# Generation: 100. 正答率(トレーニング) = 0.8032
#                 : 100. 正答率(テスト) = 0.775
# Generation: 110. 正答率(トレーニング) = 0.8292
#                 : 110. 正答率(テスト) = 0.806
# Generation: 120. 正答率(トレーニング) = 0.843
#                 : 120. 正答率(テスト) = 0.817
# Generation: 130. 正答率(トレーニング) = 0.8538
#                 : 130. 正答率(テスト) = 0.835
# Generation: 140. 正答率(トレーニング) = 0.865
#                 : 140. 正答率(テスト) = 0.842
# Generation: 150. 正答率(トレーニング) = 0.873
#                 : 150. 正答率(テスト) = 0.847
# Generation: 160. 正答率(トレーニング) = 0.8768
#                 : 160. 正答率(テスト) = 0.836
# Generation: 170. 正答率(トレーニング) = 0.8652
#                 : 170. 正答率(テスト) = 0.83
# Generation: 180. 正答率(トレーニング) = 0.8816
#                 : 180. 正答率(テスト) = 0.843
# Generation: 190. 正答率(トレーニング) = 0.891
#                 : 190. 正答率(テスト) = 0.858
# Generation: 200. 正答率(トレーニング) = 0.8912
#                 : 200. 正答率(テスト) = 0.863
# Generation: 210. 正答率(トレーニング) = 0.9036
#                 : 210. 正答率(テスト) = 0.88
# Generation: 220. 正答率(トレーニング) = 0.8874
#                 : 220. 正答率(テスト) = 0.865
# Generation: 230. 正答率(トレーニング) = 0.8964
#                 : 230. 正答率(テスト) = 0.871
# Generation: 240. 正答率(トレーニング) = 0.9194
#                 : 240. 正答率(テスト) = 0.893
# Generation: 250. 正答率(トレーニング) = 0.9054
#                 : 250. 正答率(テスト) = 0.883
# Generation: 260. 正答率(トレーニング) = 0.9132
#                 : 260. 正答率(テスト) = 0.889
# Generation: 270. 正答率(トレーニング) = 0.92
#                 : 270. 正答率(テスト) = 0.897
# Generation: 280. 正答率(トレーニング) = 0.9158
#                 : 280. 正答率(テスト) = 0.893
# Generation: 290. 正答率(トレーニング) = 0.915
#                 : 290. 正答率(テスト) = 0.889
# Generation: 300. 正答率(トレーニング) = 0.921
#                 : 300. 正答率(テスト) = 0.889
# Generation: 310. 正答率(トレーニング) = 0.9262
#                 : 310. 正答率(テスト) = 0.907
# Generation: 320. 正答率(トレーニング) = 0.9286
#                 : 320. 正答率(テスト) = 0.896
# Generation: 330. 正答率(トレーニング) = 0.927
#                 : 330. 正答率(テスト) = 0.896
# Generation: 340. 正答率(トレーニング) = 0.9292
#                 : 340. 正答率(テスト) = 0.902
# Generation: 350. 正答率(トレーニング) = 0.9328
#                 : 350. 正答率(テスト) = 0.908
# Generation: 360. 正答率(トレーニング) = 0.9332
#                 : 360. 正答率(テスト) = 0.91
# Generation: 370. 正答率(トレーニング) = 0.9366
#                 : 370. 正答率(テスト) = 0.915
# Generation: 380. 正答率(トレーニング) = 0.9356
#                 : 380. 正答率(テスト) = 0.91
# Generation: 390. 正答率(トレーニング) = 0.939
#                 : 390. 正答率(テスト) = 0.919
# Generation: 400. 正答率(トレーニング) = 0.9364
#                 : 400. 正答率(テスト) = 0.909
# Generation: 410. 正答率(トレーニング) = 0.9462
#                 : 410. 正答率(テスト) = 0.92
# Generation: 420. 正答率(トレーニング) = 0.9382
#                 : 420. 正答率(テスト) = 0.906
# Generation: 430. 正答率(トレーニング) = 0.945
#                 : 430. 正答率(テスト) = 0.918
# Generation: 440. 正答率(トレーニング) = 0.9442
#                 : 440. 正答率(テスト) = 0.922
# Generation: 450. 正答率(トレーニング) = 0.944
#                 : 450. 正答率(テスト) = 0.916
# Generation: 460. 正答率(トレーニング) = 0.9502
#                 : 460. 正答率(テスト) = 0.923
# Generation: 470. 正答率(トレーニング) = 0.9514
#                 : 470. 正答率(テスト) = 0.925
# Generation: 480. 正答率(トレーニング) = 0.9522
#                 : 480. 正答率(テスト) = 0.923
# Generation: 490. 正答率(トレーニング) = 0.9544
#                 : 490. 正答率(テスト) = 0.929
# Generation: 500. 正答率(トレーニング) = 0.9516
#                 : 500. 正答率(テスト) = 0.923
# Generation: 510. 正答率(トレーニング) = 0.952
#                 : 510. 正答率(テスト) = 0.934
# Generation: 520. 正答率(トレーニング) = 0.9514
#                 : 520. 正答率(テスト) = 0.932
# Generation: 530. 正答率(トレーニング) = 0.9582
#                 : 530. 正答率(テスト) = 0.942
# Generation: 540. 正答率(トレーニング) = 0.962
#                 : 540. 正答率(テスト) = 0.934
# Generation: 550. 正答率(トレーニング) = 0.9564
#                 : 550. 正答率(テスト) = 0.932
# Generation: 560. 正答率(トレーニング) = 0.958
#                 : 560. 正答率(テスト) = 0.936
# Generation: 570. 正答率(トレーニング) = 0.9564
#                 : 570. 正答率(テスト) = 0.93
# Generation: 580. 正答率(トレーニング) = 0.9622
#                 : 580. 正答率(テスト) = 0.937
# Generation: 590. 正答率(トレーニング) = 0.9594
#                 : 590. 正答率(テスト) = 0.932
# Generation: 600. 正答率(トレーニング) = 0.958
#                 : 600. 正答率(テスト) = 0.939
# Generation: 610. 正答率(トレーニング) = 0.963
#                 : 610. 正答率(テスト) = 0.942
# Generation: 620. 正答率(トレーニング) = 0.9628
#                 : 620. 正答率(テスト) = 0.93
# Generation: 630. 正答率(トレーニング) = 0.9584
#                 : 630. 正答率(テスト) = 0.931
# Generation: 640. 正答率(トレーニング) = 0.9632
#                 : 640. 正答率(テスト) = 0.941
# Generation: 650. 正答率(トレーニング) = 0.968
#                 : 650. 正答率(テスト) = 0.936
# Generation: 660. 正答率(トレーニング) = 0.9706
#                 : 660. 正答率(テスト) = 0.944
# Generation: 670. 正答率(トレーニング) = 0.97
#                 : 670. 正答率(テスト) = 0.937
# Generation: 680. 正答率(トレーニング) = 0.9676
#                 : 680. 正答率(テスト) = 0.939
# Generation: 690. 正答率(トレーニング) = 0.9686
#                 : 690. 正答率(テスト) = 0.944
# Generation: 700. 正答率(トレーニング) = 0.9672
#                 : 700. 正答率(テスト) = 0.933
# Generation: 710. 正答率(トレーニング) = 0.9554
#                 : 710. 正答率(テスト) = 0.933
# Generation: 720. 正答率(トレーニング) = 0.9682
#                 : 720. 正答率(テスト) = 0.939
# Generation: 730. 正答率(トレーニング) = 0.9722
#                 : 730. 正答率(テスト) = 0.939
# Generation: 740. 正答率(トレーニング) = 0.9722
#                 : 740. 正答率(テスト) = 0.943
# Generation: 750. 正答率(トレーニング) = 0.9712
#                 : 750. 正答率(テスト) = 0.944
# Generation: 760. 正答率(トレーニング) = 0.971
#                 : 760. 正答率(テスト) = 0.943
# Generation: 770. 正答率(トレーニング) = 0.9704
#                 : 770. 正答率(テスト) = 0.941
# Generation: 780. 正答率(トレーニング) = 0.9686
#                 : 780. 正答率(テスト) = 0.935
# Generation: 790. 正答率(トレーニング) = 0.9712
#                 : 790. 正答率(テスト) = 0.94
# Generation: 800. 正答率(トレーニング) = 0.9722
#                 : 800. 正答率(テスト) = 0.943
# Generation: 810. 正答率(トレーニング) = 0.9702
#                 : 810. 正答率(テスト) = 0.932
# Generation: 820. 正答率(トレーニング) = 0.9744
#                 : 820. 正答率(テスト) = 0.952
# Generation: 830. 正答率(トレーニング) = 0.9722
#                 : 830. 正答率(テスト) = 0.945
# Generation: 840. 正答率(トレーニング) = 0.9744
#                 : 840. 正答率(テスト) = 0.939
# Generation: 850. 正答率(トレーニング) = 0.979
#                 : 850. 正答率(テスト) = 0.948
# Generation: 860. 正答率(トレーニング) = 0.98
#                 : 860. 正答率(テスト) = 0.949
# Generation: 870. 正答率(トレーニング) = 0.9784
#                 : 870. 正答率(テスト) = 0.946
# Generation: 880. 正答率(トレーニング) = 0.9748
#                 : 880. 正答率(テスト) = 0.941
# Generation: 890. 正答率(トレーニング) = 0.9742
#                 : 890. 正答率(テスト) = 0.951
# Generation: 900. 正答率(トレーニング) = 0.9796
#                 : 900. 正答率(テスト) = 0.947
# Generation: 910. 正答率(トレーニング) = 0.9766
#                 : 910. 正答率(テスト) = 0.941
# Generation: 920. 正答率(トレーニング) = 0.9748
#                 : 920. 正答率(テスト) = 0.935
# Generation: 930. 正答率(トレーニング) = 0.9776
#                 : 930. 正答率(テスト) = 0.947
# Generation: 940. 正答率(トレーニング) = 0.9716
#                 : 940. 正答率(テスト) = 0.937
# Generation: 950. 正答率(トレーニング) = 0.9736
#                 : 950. 正答率(テスト) = 0.941
# Generation: 960. 正答率(トレーニング) = 0.9764
#                 : 960. 正答率(テスト) = 0.954
# Generation: 970. 正答率(トレーニング) = 0.9768
#                 : 970. 正答率(テスト) = 0.948
# Generation: 980. 正答率(トレーニング) = 0.9794
#                 : 980. 正答率(テスト) = 0.949
# Generation: 990. 正答率(トレーニング) = 0.9758
#                 : 990. 正答率(テスト) = 0.946
# Generation: 1000. 正答率(トレーニング) = 0.9814
#                 : 1000. 正答率(テスト) = 0.948

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## [try] DoubleConvNetをアレンジしよう
# pooling層を一つ減らしたものに変えてみよう<br>
# conv - relu - conv - relu - pool - affine - relu - affine - softmax
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
